# %%
#!/bin/sh

'''In this workbook, I will be querying data from the NYC OpenData API and storing it into a MySQL database. 
    I will create both a time-invariant (store info) and time-varying (inspection info) database. '''

import requests
import json

# Connect to the Citibike API and fetch the data
def getOpenData():
    ''' 
    Connects to the NYC OpenData Restaurant Inspection Results API, and returns back a list
    of dictionaries, each dictionary corresponding
    to an inspection instance
    '''
    # Let's get the data from the Citibike API
    url = 'https://data.cityofnewyork.us/resource/9w7m-hzhe.json?$$app_token=yewO3Q85FrsdtwG6azAWeMPol'
    resp = requests.get(url)
    results = json.loads(resp.text)
    return results

store_data = getOpenData()
store_data
# Out:
# [{u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'STATEN ISLAND',
#   u'building': u'1660      ',
#   u'camis': u'40395935',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Hamburgers',
#   u'dba': u"MCDONALD'S",
#   u'grade': u'A',
#   u'grade_date': u'2015-05-12T00:00:00.000',
#   u'inspection_date': u'2015-05-12T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7184943400',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'12',
#   u'street': u'RICHMOND AVENUE                                   ',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10314'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'505       ',
#   u'camis': u'41216379',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'EASTERN BLOC',
#   u'inspection_date': u'2015-10-29T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2127772555',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'EAST    6 STREET                                  ',
#   u'violation_code': u'04N',
#   u'violation_description': u'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility\x1as food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.',
#   u'zipcode': u'10009'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'160158',
#   u'camis': u'41670880',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'WESTSIDE BREWHOUSE',
#   u'inspection_date': u'2013-10-09T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2123378301',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'27',
#   u'street': u'WEST   25 STREET',
#   u'violation_code': u'04H',
#   u'violation_description': u'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.',
#   u'zipcode': u'10001'},
#  {u'action': u'Establishment re-closed by DOHMH',
#   u'boro': u'BROOKLYN',
#   u'building': u'135',
#   u'camis': u'41149565',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Caribbean',
#   u'dba': u"CAS' WEST INDIAN & AMERICAN RESTAURANT",
#   u'inspection_date': u'2015-07-20T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Reopening Inspection',
#   u'phone': u'7188041075',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'KINGSTON AVENUE',
#   u'violation_code': u'04N',
#   u'violation_description': u'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility\x1as food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.',
#   u'zipcode': u'11213'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'228       ',
#   u'camis': u'41565705',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'THE RUM HOUSE',
#   u'inspection_date': u'2013-07-31T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'6464906924',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'20',
#   u'street': u'WEST   47 STREET                                  ',
#   u'violation_code': u'10H',
#   u'violation_description': u'Proper sanitization not provided for utensil ware washing operation.',
#   u'zipcode': u'10036'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'160',
#   u'camis': u'41545743',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Bakery',
#   u'dba': u'HAPPY STAR BAKERY',
#   u'inspection_date': u'2014-09-29T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2126088899',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'EAST BROADWAY',
#   u'violation_code': u'04M',
#   u'violation_description': u"Live roaches present in facility's food and/or non-food areas.",
#   u'zipcode': u'10002'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'947       ',
#   u'camis': u'40374325',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'French',
#   u'dba': u'LA MEDITERRANEE RESTAURANT',
#   u'inspection_date': u'2013-03-13T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2127554155',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'51',
#   u'street': u'2 AVENUE                                          ',
#   u'violation_code': u'02H',
#   u'violation_description': u'Food not cooled by an approved method whereby the internal product temperature is reduced from 140\xc2\xba F to 70\xc2\xba F or less within 2 hours, and from 70\xc2\xba F to 41\xc2\xba F or less within 4 additional hours.',
#   u'zipcode': u'10022'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'2825',
#   u'camis': u'41201169',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Chinese',
#   u'dba': u'YONG SHENG RESTAURANT',
#   u'grade': u'B',
#   u'grade_date': u'2014-08-28T00:00:00.000',
#   u'inspection_date': u'2014-08-28T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2128622702',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'20',
#   u'street': u'   8 AVENUE                             ',
#   u'violation_code': u'06A',
#   u'violation_description': u'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.',
#   u'zipcode': u'10039'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'110',
#   u'camis': u'40837666',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Tapas',
#   u'dba': u'VERLAINE',
#   u'grade': u'A',
#   u'grade_date': u'2015-08-04T00:00:00.000',
#   u'inspection_date': u'2015-08-04T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2126142494',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'RIVINGTON STREET',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xc2\xba F (smoked fish and reduced oxygen packaged foods above 38 \xc2\xbaF) except during necessary preparation.',
#   u'zipcode': u'10002'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'184',
#   u'camis': u'50002954',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u"EDDIE'S DELI & PIZZA",
#   u'inspection_date': u'2013-10-04T00:00:00.000',
#   u'inspection_type': u'Pre-permit (Non-operational) / Initial Inspection',
#   u'phone': u'2123694789',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'2',
#   u'street': u'E 116TH ST',
#   u'violation_code': u'10A',
#   u'violation_description': u'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.',
#   u'zipcode': u'10029'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'51',
#   u'camis': u'41635973',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'THE KENT ALE HOUSE',
#   u'inspection_date': u'2012-09-04T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'3472278624',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'17',
#   u'street': u'KENT AVENUE',
#   u'violation_code': u'04A',
#   u'violation_description': u'Food Protection Certificate not held by supervisor of food operations.',
#   u'zipcode': u'11249'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'67',
#   u'camis': u'41567020',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Salads',
#   u'dba': u'GREENSTREETS SALADS',
#   u'inspection_date': u'2015-06-15T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'3474057956',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'48',
#   u'street': u'IRVING AVENUE',
#   u'violation_code': u'05F',
#   u'violation_description': u'Insufficient or no refrigerated or hot holding equipment to keep potentially hazardous foods at required temperatures.',
#   u'zipcode': u'11237'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'141',
#   u'camis': u'50036660',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Japanese',
#   u'dba': u'KIKOO SUSHI',
#   u'grade': u'C',
#   u'grade_date': u'2015-06-22T00:00:00.000',
#   u'inspection_date': u'2015-06-22T00:00:00.000',
#   u'inspection_type': u'Pre-permit (Operational) / Re-inspection',
#   u'phone': u'2125333888',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'42',
#   u'street': u'1ST AVE',
#   u'violation_code': u'02B',
#   u'violation_description': u'Hot food item not held at or above 140\xba F.',
#   u'zipcode': u'10003'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'354',
#   u'camis': u'41473636',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u'HECHO EN DUMBO',
#   u'grade': u'B',
#   u'grade_date': u'2013-08-21T00:00:00.000',
#   u'inspection_date': u'2013-08-21T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2129374245',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'15',
#   u'street': u'BOWERY',
#   u'violation_code': u'04L',
#   u'violation_description': u"Evidence of mice or live mice present in facility's food and/or non-food areas.",
#   u'zipcode': u'10012'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BRONX',
#   u'building': u'5700',
#   u'camis': u'40656594',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Steak',
#   u'dba': u'RIVERDALE STEAK HOUSE',
#   u'inspection_date': u'2015-10-14T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7185499946',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'16',
#   u'street': u'RIVERDALE AVENUE',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10471'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'15        ',
#   u'camis': u'41596870',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Chinese',
#   u'dba': u'WO HOP CITY',
#   u'inspection_date': u'2014-03-10T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2125663841',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'19',
#   u'street': u'MOTT STREET                                       ',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10013'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'15024',
#   u'camis': u'41164934',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Korean',
#   u'dba': u'DAE DONG MANOR',
#   u'inspection_date': u'2013-11-13T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7189392555',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'24',
#   u'street': u'NORTHERN BOULEVARD',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11354'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'53',
#   u'camis': u'41019942',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Scandinavian',
#   u'dba': u'SMORGAS CHEF/ CREPES DU NORD',
#   u'grade': u'A',
#   u'grade_date': u'2015-09-01T00:00:00.000',
#   u'inspection_date': u'2015-09-01T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2124223500',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'12',
#   u'street': u'STONE STREET',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10004'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'104',
#   u'camis': u'50043861',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'LIONS BEER STORE',
#   u'grade': u'A',
#   u'grade_date': u'2016-01-21T00:00:00.000',
#   u'inspection_date': u'2016-01-21T00:00:00.000',
#   u'inspection_type': u'Pre-permit (Operational) / Initial Inspection',
#   u'phone': u'2124750595',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'12',
#   u'street': u'2ND AVE',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xc2\xba F (smoked fish and reduced oxygen packaged foods above 38 \xc2\xbaF) except during necessary preparation.',
#   u'zipcode': u'10003'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'5610',
#   u'camis': u'50014720',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Russian',
#   u'dba': u'CAFE SHIRIN',
#   u'grade': u'A',
#   u'grade_date': u'2015-08-26T00:00:00.000',
#   u'inspection_date': u'2015-08-26T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7185766633',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'NEW UTRECHT AVE',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xc2\xba F (smoked fish and reduced oxygen packaged foods above 38 \xc2\xbaF) except during necessary preparation.',
#   u'zipcode': u'11219'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'9502      ',
#   u'camis': u'41172924',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'FORT HAMILTON DINER',
#   u'inspection_date': u'2014-04-02T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7182385151',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'19',
#   u'street': u'FOURTH AVENUE                                     ',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11209'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'5123',
#   u'camis': u'41048074',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Jewish/Kosher',
#   u'dba': u'GLATT ALA CARTE',
#   u'grade': u'A',
#   u'grade_date': u'2012-06-06T00:00:00.000',
#   u'inspection_date': u'2012-06-06T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7184386675',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'18 AVENUE',
#   u'violation_code': u'10B',
#   u'violation_description': u'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.',
#   u'zipcode': u'11204'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'493',
#   u'camis': u'40378970',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Pizza',
#   u'dba': u"CAESAR'S PALACE",
#   u'grade': u'A',
#   u'grade_date': u'2014-03-19T00:00:00.000',
#   u'inspection_date': u'2014-03-19T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2127247886',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'12',
#   u'street': u'AMSTERDAM AVENUE',
#   u'violation_code': u'06C',
#   u'violation_description': u'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.',
#   u'zipcode': u'10024'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'209       ',
#   u'camis': u'40922818',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u'EL TAPATIO MEXICAN RESTAURANT',
#   u'grade': u'C',
#   u'grade_date': u'2013-01-18T00:00:00.000',
#   u'inspection_date': u'2013-01-18T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2128763055',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'42',
#   u'street': u'EAST  116 STREET                                  ',
#   u'violation_code': u'04L',
#   u'violation_description': u"Evidence of mice or live mice present in facility's food and/or non-food areas.",
#   u'zipcode': u'10029'},
#  {u'action': u'No violations were recorded at the time of this inspection.',
#   u'boro': u'MANHATTAN',
#   u'building': u'128',
#   u'camis': u'41183605',
#   u'critical_flag': u'Not Applicable',
#   u'cuisine_description': u'American ',
#   u'dba': u'TROPICAL 128',
#   u'inspection_date': u'2014-05-13T00:00:00.000',
#   u'inspection_type': u'Trans Fat / Compliance Inspection',
#   u'phone': u'2129258219',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'street': u'ELIZABETH STREET',
#   u'zipcode': u'10013'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'121',
#   u'camis': u'50003456',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Caf\xe9/Coffee/Tea',
#   u'dba': u'LUNA',
#   u'inspection_date': u'2014-01-24T00:00:00.000',
#   u'inspection_type': u'Administrative Miscellaneous / Initial Inspection',
#   u'phone': u'6468072167',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'street': u'W 29TH ST',
#   u'violation_code': u'22C',
#   u'violation_description': u'Bulb not shielded or shatterproof, in areas where there is extreme heat, temperature changes, or where accidental contact may occur.',
#   u'zipcode': u'10001'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'53',
#   u'camis': u'41629953',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Japanese',
#   u'dba': u'SHINOBI RAMEN',
#   u'grade': u'A',
#   u'grade_date': u'2014-09-24T00:00:00.000',
#   u'inspection_date': u'2014-09-24T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'6463429014',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'10',
#   u'street': u'MORGAN AVENUE',
#   u'violation_code': u'02B',
#   u'violation_description': u'Hot food item not held at or above 140\xc2\xba F.',
#   u'zipcode': u'11237'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'212',
#   u'camis': u'50001203',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Japanese',
#   u'dba': u'AKI SUSHI',
#   u'grade': u'A',
#   u'grade_date': u'2014-06-30T00:00:00.000',
#   u'inspection_date': u'2014-06-30T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2128938266',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'E 52ND STREET',
#   u'violation_code': u'04M',
#   u'violation_description': u"Live roaches present in facility's food and/or non-food areas.",
#   u'zipcode': u'10022'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'76-07',
#   u'camis': u'50001655',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Spanish',
#   u'dba': u'EL RICO TINTO BAKERY',
#   u'inspection_date': u'2015-01-24T00:00:00.000',
#   u'inspection_type': u'Smoke-Free Air Act / Re-inspection',
#   u'phone': u'7184241324',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'street': u'37TH AVENUE',
#   u'violation_code': u'15L',
#   u'violation_description': u'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.',
#   u'zipcode': u'11372'},
#  {u'action': u'Establishment re-opened by DOHMH',
#   u'boro': u'QUEENS',
#   u'building': u'2512',
#   u'camis': u'40639406',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Pizza/Italian',
#   u'dba': u'TASTY FAST FOOD',
#   u'grade': u'C',
#   u'grade_date': u'2014-03-19T00:00:00.000',
#   u'inspection_date': u'2014-03-19T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Reopening Inspection',
#   u'phone': u'7184820015',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'34 AVENUE',
#   u'violation_code': u'04M',
#   u'violation_description': u"Live roaches present in facility's food and/or non-food areas.",
#   u'zipcode': u'11106'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'7701',
#   u'camis': u'41591126',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Bangladeshi',
#   u'dba': u'ROSE BENGAL',
#   u'grade': u'A',
#   u'grade_date': u'2016-01-19T00:00:00.000',
#   u'inspection_date': u'2016-01-19T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7188485300',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'101 AVENUE',
#   u'violation_code': u'04L',
#   u'violation_description': u"Evidence of mice or live mice present in facility's food and/or non-food areas.",
#   u'zipcode': u'11416'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'123',
#   u'camis': u'40978593',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   u'dba': u'BONAO BAR AND GRILL',
#   u'grade': u'A',
#   u'grade_date': u'2014-02-05T00:00:00.000',
#   u'inspection_date': u'2014-02-05T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7183460285',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'JAMAICA AVENUE',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xba F (smoked fish and reduced oxygen packaged foods above 38 \xbaF) except during necessary preparation.',
#   u'zipcode': u'11207'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'1118 ',
#   u'camis': u'41399687',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'SYCAMORE',
#   u'inspection_date': u'2012-05-31T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'3472405850',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'24',
#   u'street': u'CORTELYOU ROAD',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11218'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'728       ',
#   u'camis': u'40397056',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Jewish/Kosher',
#   u'dba': u'SHARMEL CATERERS',
#   u'grade': u'A',
#   u'grade_date': u'2015-09-18T00:00:00.000',
#   u'inspection_date': u'2015-09-18T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7183273575',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'EMPIRE AVENUE                                     ',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11691'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'112',
#   u'camis': u'41546741',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'JUNIPER',
#   u'inspection_date': u'2014-08-16T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7187828777',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'33',
#   u'street': u'BERRY STREET',
#   u'violation_code': u'10H',
#   u'violation_description': u'Proper sanitization not provided for utensil ware washing operation.',
#   u'zipcode': u'11211'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'75',
#   u'camis': u'50008145',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u"MIGHTY QUINN'S BBQ",
#   u'inspection_date': u'2015-03-17T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'6465247889',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'18',
#   u'street': u'GREENWICH AVE',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10014'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'11522',
#   u'camis': u'41168585',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Caribbean',
#   u'dba': u'SUGAZ BAR',
#   u'inspection_date': u'2013-05-09T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7183232453',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'21',
#   u'street': u'LIBERTY AVENUE',
#   u'violation_code': u'04L',
#   u'violation_description': u"Evidence of mice or live mice present in facility's food and/or non-food areas.",
#   u'zipcode': u'11419'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BRONX',
#   u'building': u'2',
#   u'camis': u'41686184',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Pizza',
#   u'dba': u'OLI 99\xa2 FRESH PIZZA',
#   u'grade': u'A',
#   u'grade_date': u'2014-12-16T00:00:00.000',
#   u'inspection_date': u'2014-12-16T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7186180025',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'8',
#   u'street': u'EAST BURNSIDE AVENUE',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10453'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'2158      ',
#   u'camis': u'40582103',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Chicken',
#   u'dba': u"MAMA'S FRIED CHICKEN",
#   u'grade': u'B',
#   u'grade_date': u'2015-06-11T00:00:00.000',
#   u'inspection_date': u'2015-06-11T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2125314595',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'20',
#   u'street': u'8 AVENUE                                          ',
#   u'violation_code': u'10H',
#   u'violation_description': u'Proper sanitization not provided for utensil ware washing operation.',
#   u'zipcode': u'10026'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'301',
#   u'camis': u'50045498',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u'MI TACO SANTANA',
#   u'grade': u'A',
#   u'grade_date': u'2016-02-11T00:00:00.000',
#   u'inspection_date': u'2016-02-11T00:00:00.000',
#   u'inspection_type': u'Pre-permit (Operational) / Initial Inspection',
#   u'phone': u'3479525093',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'9',
#   u'street': u'KEAP ST',
#   u'violation_code': u'02H',
#   u'violation_description': u'Food not cooled by an approved method whereby the internal product temperature is reduced from 140\xc2\xba F to 70\xc2\xba F or less within 2 hours, and from 70\xc2\xba F to 41\xc2\xba F or less within 4 additional hours.',
#   u'zipcode': u'11211'},
#  {u'action': u'Establishment Closed by DOHMH.  Violations were cited in the following area(s) and those requiring immediate action were addressed.',
#   u'boro': u'MANHATTAN',
#   u'building': u'209       ',
#   u'camis': u'40922818',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u'EL TAPATIO MEXICAN RESTAURANT',
#   u'inspection_date': u'2015-10-14T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2128763055',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'62',
#   u'street': u'EAST  116 STREET                                  ',
#   u'violation_code': u'04M',
#   u'violation_description': u"Live roaches present in facility's food and/or non-food areas.",
#   u'zipcode': u'10029'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'506',
#   u'camis': u'41504915',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'THE FIFTH ESTATE',
#   u'grade': u'A',
#   u'grade_date': u'2014-09-17T00:00:00.000',
#   u'inspection_date': u'2014-09-17T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7188400089',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'6',
#   u'street': u'5 AVENUE',
#   u'violation_code': u'04L',
#   u'violation_description': u"Evidence of mice or live mice present in facility's food and/or non-food areas.",
#   u'zipcode': u'11215'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BRONX',
#   u'building': u'380',
#   u'camis': u'50003104',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Pizza/Italian',
#   u'dba': u'BEDFORD PIZZA CAFE',
#   u'grade': u'B',
#   u'grade_date': u'2015-11-20T00:00:00.000',
#   u'inspection_date': u'2015-11-20T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'9178010770',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'18',
#   u'street': u'BEDFORD PARK BLVD',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10458'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'0',
#   u'camis': u'41566509',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u"MEXI JOE'S GRILL",
#   u'grade': u'A',
#   u'grade_date': u'2014-01-09T00:00:00.000',
#   u'inspection_date': u'2014-01-09T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7184467600',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'LAGUARDIA AIRPORT',
#   u'violation_code': u'02B',
#   u'violation_description': u'Hot food item not held at or above 140\xba F.',
#   u'zipcode': u'11369'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'8301',
#   u'camis': u'40633995',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u'TACO BELL',
#   u'grade': u'A',
#   u'grade_date': u'2014-04-15T00:00:00.000',
#   u'inspection_date': u'2014-04-15T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7184789530',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'37 AVENUE',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11372'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'12696',
#   u'camis': u'41299050',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Delicatessen',
#   u'dba': u'MASTER EXPRESS DELI & RESTAURANT',
#   u'inspection_date': u'2014-07-03T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'3476533915',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'30',
#   u'street': u'WILLETS POINT BOULEVARD',
#   u'violation_code': u'02B',
#   u'violation_description': u'Hot food item not held at or above 140\xba F.',
#   u'zipcode': u'11368'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BRONX',
#   u'building': u'1690',
#   u'camis': u'40926214',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   u'dba': u'LA MONEDA RESTAURANT',
#   u'inspection_date': u'2015-10-28T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7189012787',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'21',
#   u'street': u'JEROME AVENUE',
#   u'violation_code': u'04A',
#   u'violation_description': u'Food Protection Certificate not held by supervisor of food operations.',
#   u'zipcode': u'10453'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'1011',
#   u'camis': u'41598755',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Caf\xe9/Coffee/Tea',
#   u'dba': u'TROOST',
#   u'inspection_date': u'2015-06-26T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'3478896761',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'23',
#   u'street': u'MANHATTAN AVENUE',
#   u'violation_code': u'06D',
#   u'violation_description': u'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.',
#   u'zipcode': u'11222'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'50        ',
#   u'camis': u'50003284',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Spanish',
#   u'dba': u'KARMA RESTAURANT',
#   u'grade': u'B',
#   u'grade_date': u'2014-12-03T00:00:00.000',
#   u'inspection_date': u'2014-12-03T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7184430098',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'17',
#   u'street': u'MALCOLM X BOULEVARD                                                                                 ',
#   u'violation_code': u'02B',
#   u'violation_description': u'Hot food item not held at or above 140\xba F.',
#   u'zipcode': u'11221'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'666',
#   u'camis': u'50044750',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Spanish',
#   u'dba': u'PARAISO ZONA VIP RESTAURANT BAR',
#   u'grade': u'A',
#   u'grade_date': u'2016-01-16T00:00:00.000',
#   u'inspection_date': u'2016-01-16T00:00:00.000',
#   u'inspection_type': u'Pre-permit (Operational) / Initial Inspection',
#   u'phone': u'3473842643',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'10',
#   u'street': u'SENECA AVE',
#   u'violation_code': u'04L',
#   u'violation_description': u"Evidence of mice or live mice present in facility's food and/or non-food areas.",
#   u'zipcode': u'11385'},
#  {u'action': u'Establishment re-opened by DOHMH',
#   u'boro': u'QUEENS',
#   u'building': u'10430',
#   u'camis': u'41086368',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   u'dba': u'LUZ DE AMERICA RESTAURANT',
#   u'grade': u'C',
#   u'grade_date': u'2013-10-30T00:00:00.000',
#   u'inspection_date': u'2013-10-30T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Reopening Inspection',
#   u'phone': u'7186512060',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'3',
#   u'street': u'ROOSEVELT AVENUE',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11368'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'185',
#   u'camis': u'41453018',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'ROCK BAR',
#   u'inspection_date': u'2013-05-31T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2126751864',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'37',
#   u'street': u'CHRISTOPHER STREET',
#   u'violation_code': u'06D',
#   u'violation_description': u'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.',
#   u'zipcode': u'10014'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'225       ',
#   u'camis': u'41635064',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Mexican',
#   u'dba': u'WYTHE DINER/ LA ESQUINA',
#   u'inspection_date': u'2013-08-28T00:00:00.000',
#   u'inspection_type': u'Trans Fat / Initial Inspection',
#   u'phone': u'7183935500',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'street': u'WYTHE AVENUE                                      ',
#   u'violation_code': u'16B',
#   u'violation_description': u'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer\x1as documentation not maintained on site.',
#   u'zipcode': u'11249'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'170',
#   u'camis': u'41431046',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'JOSEPH LEONARD',
#   u'grade': u'A',
#   u'grade_date': u'2013-01-18T00:00:00.000',
#   u'inspection_date': u'2013-01-18T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'6463198632',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'WAVERLY PLACE',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xba F (smoked fish and reduced oxygen packaged foods above 38 \xbaF) except during necessary preparation.',
#   u'zipcode': u'10014'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'9801',
#   u'camis': u'40668305',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Peruvian',
#   u'dba': u'EL ANZUELO FINO RESTAURANT',
#   u'inspection_date': u'2012-04-09T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7188460909',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'27',
#   u'street': u'JAMAICA AVENUE',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xc2\xba F (smoked fish and reduced oxygen packaged foods above 38 \xc2\xbaF) except during necessary preparation.',
#   u'zipcode': u'11421'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'11606',
#   u'camis': u'40724277',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Chinese',
#   u'dba': u"NEW KIM'S RESTAURANT",
#   u'inspection_date': u'2013-08-01T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7183184881',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'23',
#   u'street': u'ROCKAWAY BEACH BOULEVARD',
#   u'violation_code': u'08B',
#   u'violation_description': u'Covered garbage receptacle not provided or inadequate, except that garbage receptacle may be uncovered during active use. Garbage storage area not properly constructed or maintained; grinder or compactor dirty.',
#   u'zipcode': u'11694'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'2049',
#   u'camis': u'41262497',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Hamburgers',
#   u'dba': u"MCDONALD'S",
#   u'grade': u'A',
#   u'grade_date': u'2015-03-24T00:00:00.000',
#   u'inspection_date': u'2015-03-24T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2127240435',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'10',
#   u'street': u'BROADWAY',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10023'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'251',
#   u'camis': u'50035967',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Caf\xc3\xa9/Coffee/Tea',
#   u'dba': u'REX CHELSEA',
#   u'grade': u'A',
#   u'grade_date': u'2015-11-23T00:00:00.000',
#   u'inspection_date': u'2015-11-23T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'9176897320',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'W 23RD ST',
#   u'violation_code': u'04N',
#   u'violation_description': u'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility\x1as food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.',
#   u'zipcode': u'10011'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'600',
#   u'camis': u'50002724',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'THE CANNIBAL',
#   u'grade': u'A',
#   u'grade_date': u'2015-02-27T00:00:00.000',
#   u'inspection_date': u'2015-02-27T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2126865480',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'8',
#   u'street': u'11TH AVE',
#   u'violation_code': u'06D',
#   u'violation_description': u'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.',
#   u'zipcode': u'10036'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'228       ',
#   u'camis': u'41231957',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Japanese',
#   u'dba': u'DIECI',
#   u'grade': u'C',
#   u'grade_date': u'2013-04-02T00:00:00.000',
#   u'inspection_date': u'2013-04-02T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2123879545',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'39',
#   u'street': u'EAST   10 STREET                                  ',
#   u'violation_code': u'09C',
#   u'violation_description': u'Food contact surface not properly maintained.',
#   u'zipcode': u'10003'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'3         ',
#   u'camis': u'41011887',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'THE CITY BAKERY',
#   u'inspection_date': u'2012-10-24T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2123661414',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'43',
#   u'street': u'WEST   18 STREET                                  ',
#   u'violation_code': u'04M',
#   u'violation_description': u"Live roaches present in facility's food and/or non-food areas.",
#   u'zipcode': u'10011'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'561',
#   u'camis': u'50001589',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Thai',
#   u'dba': u'TUNG THONG THAI RESTAURANT',
#   u'inspection_date': u'2014-11-07T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2127955995',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'WEST 169TH STREET',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10032'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BRONX',
#   u'building': u'2350      ',
#   u'camis': u'41394908',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Donuts',
#   u'dba': u"DUNKIN' DONUTS",
#   u'inspection_date': u'2015-09-30T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7182205156',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'39',
#   u'street': u'JEROME AVENUE                                     ',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10468'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'236',
#   u'camis': u'41282946',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Mediterranean',
#   u'dba': u'ILILI RESTAURANT',
#   u'inspection_date': u'2014-07-24T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2126832929',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'25',
#   u'street': u'5 AVENUE',
#   u'violation_code': u'02G',
# ...
#   u'inspection_date': u'2014-10-24T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2127422787',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'SOUTH STREET',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10004'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'1271',
#   u'camis': u'40545130',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'SPEEDY DELI',
#   u'grade': u'B',
#   u'grade_date': u'2014-06-26T00:00:00.000',
#   u'inspection_date': u'2014-06-26T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2126838997',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'14',
#   u'street': u'BROADWAY',
#   u'violation_code': u'04N',
#   u'violation_description': u'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility\x1as food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.',
#   u'zipcode': u'10001'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'2024',
#   u'camis': u'41633093',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   u'dba': u'EL CERRITO DEL CARMEN RESTAURANT',
#   u'inspection_date': u'2014-08-14T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7183397907',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'33',
#   u'street': u'MCDONALD AVENUE',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'11223'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'158160    ',
#   u'camis': u'40550765',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u"ARETSKY'S PATROON",
#   u'grade': u'B',
#   u'grade_date': u'2014-01-28T00:00:00.000',
#   u'inspection_date': u'2014-01-28T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2128837373',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'20',
#   u'street': u'EAST   46 STREET                                  ',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10017'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'13        ',
#   u'camis': u'41586226',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Chinese',
#   u'dba': u'GOOD GOOD TASTE',
#   u'inspection_date': u'2014-02-11T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2129644888',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'27',
#   u'street': u'MARKET STREET                                                                                       ',
#   u'violation_code': u'04M',
#   u'violation_description': u"Live roaches present in facility's food and/or non-food areas.",
#   u'zipcode': u'10002'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'287',
#   u'camis': u'40611479',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Italian',
#   u'dba': u"JOE'S OF AVE U",
#   u'inspection_date': u'2015-08-05T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7184494285',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'60',
#   u'street': u'AVENUE U',
#   u'violation_code': u'04J',
#   u'violation_description': u'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.',
#   u'zipcode': u'11223'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'880',
#   u'camis': u'41436866',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u"MCDONALD'S",
#   u'inspection_date': u'2014-04-02T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7188714242',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'24',
#   u'street': u'CONEY ISLAND AVE',
#   u'violation_code': u'04A',
#   u'violation_description': u'Food Protection Certificate not held by supervisor of food operations.',
#   u'zipcode': u'11218'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'STATEN ISLAND',
#   u'building': u'2341',
#   u'camis': u'41322588',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Ice Cream, Gelato, Yogurt, Ices',
#   u'dba': u'COLD STONE CREAMERY',
#   u'inspection_date': u'2014-03-19T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7189835700',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'11',
#   u'street': u'RICHMOND AVENUE',
#   u'violation_code': u'06E',
#   u'violation_description': u'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.',
#   u'zipcode': u'10314'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'57',
#   u'camis': u'41702880',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Japanese',
#   u'dba': u'RAKU II ITS JAPANESE',
#   u'inspection_date': u'2013-09-13T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2128731220',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'25',
#   u'street': u'WEST   76 STREET',
#   u'violation_code': u'02G',
#   u'violation_description': u'Cold food item held above 41\xba F (smoked fish and reduced oxygen packaged foods above 38 \xbaF) except during necessary preparation.',
#   u'zipcode': u'10023'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'125       ',
#   u'camis': u'41602776',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Chinese',
#   u'dba': u"FRIENDLY'S",
#   u'inspection_date': u'2013-10-08T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7188548500',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'CHURCH AVENUE                                     ',
#   u'violation_code': u'09A',
#   u'violation_description': u'Canned food product observed dented and not segregated from other consumable food items.',
#   u'zipcode': u'11218'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'1335',
#   u'camis': u'41372356',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'HILTON NEW YORK MAIN KITCHEN',
#   u'inspection_date': u'2015-05-14T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2125867000',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'50',
#   u'street': u'AVENUE OF THE AMERICAS',
#   u'violation_code': u'04H',
#   u'violation_description': u'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.',
#   u'zipcode': u'10019'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'24501',
#   u'camis': u'50035570',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Chicken',
#   u'dba': u'POPEYES LOUISIANA KITCHEN',
#   u'grade': u'A',
#   u'grade_date': u'2015-05-04T00:00:00.000',
#   u'inspection_date': u'2015-05-04T00:00:00.000',
#   u'inspection_type': u'Pre-permit (Operational) / Initial Inspection',
#   u'phone': u'7182763010',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'12',
#   u'street': u'FRANCIS LEWIS BLVD',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11422'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'625',
#   u'camis': u'40363298',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'CAFE METRO',
#   u'grade': u'A',
#   u'grade_date': u'2014-01-10T00:00:00.000',
#   u'inspection_date': u'2014-01-10T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'2127149342',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'9',
#   u'street': u'8 AVENUE',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10018'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'433',
#   u'camis': u'41604359',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Vietnamese/Cambodian/Malaysia',
#   u'dba': u'HENRY',
#   u'grade': u'A',
#   u'grade_date': u'2014-04-30T00:00:00.000',
#   u'inspection_date': u'2014-04-30T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7187888882',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'9',
#   u'street': u'7 AVENUE',
#   u'violation_code': u'02B',
#   u'violation_description': u'Hot food item not held at or above 140\xba F.',
#   u'zipcode': u'11215'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'1419',
#   u'camis': u'40863935',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Hamburgers',
#   u'dba': u'BURGER KING',
#   u'inspection_date': u'2015-10-08T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2129274787',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'14',
#   u'street': u'ST NICHOLAS AVENUE',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10033'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'339       ',
#   u'camis': u'50001204',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'MON CHER MARKET',
#   u'inspection_date': u'2015-02-12T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2129650007',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'BROADWAY                                          ',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'10013'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'0',
#   u'camis': u'41108575',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'SOHO BISTRO',
#   u'grade': u'A',
#   u'grade_date': u'2014-02-27T00:00:00.000',
#   u'inspection_date': u'2014-02-27T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Re-inspection',
#   u'phone': u'7186561012',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'13',
#   u'street': u'JFK INTERNATIONAL AIRPORT',
#   u'violation_code': u'10F',
#   u'violation_description': u'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.',
#   u'zipcode': u'11430'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'MANHATTAN',
#   u'building': u'217',
#   u'camis': u'41605053',
#   u'critical_flag': u'Not Critical',
#   u'cuisine_description': u'Indian',
#   u'dba': u'BUKHARA GRILL',
#   u'inspection_date': u'2014-04-18T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'2128882839',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'21',
#   u'street': u'EAST   49 STREET',
#   u'violation_code': u'08A',
#   u'violation_description': u'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.',
#   u'zipcode': u'10017'},
#  {u'action': u'Establishment Closed by DOHMH.  Violations were cited in the following area(s) and those requiring immediate action were addressed.',
#   u'boro': u'QUEENS',
#   u'building': u'3411',
#   u'camis': u'41461985',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Japanese',
#   u'dba': u'MATSU SUSHI',
#   u'inspection_date': u'2013-08-03T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7187267029',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'56',
#   u'street': u'30 AVENUE',
#   u'violation_code': u'06A',
#   u'violation_description': u'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.',
#   u'zipcode': u'11103'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'QUEENS',
#   u'building': u'24510',
#   u'camis': u'41274069',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'Chinese',
#   u'dba': u'OCEAN CHINESE RESTAURANT',
#   u'grade': u'A',
#   u'grade_date': u'2013-09-23T00:00:00.000',
#   u'inspection_date': u'2013-09-23T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7182798893',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'12',
#   u'street': u'HORACE HARDING EXPRESSWAY',
#   u'violation_code': u'06F',
#   u'violation_description': u'Wiping cloths soiled or not stored in sanitizing solution.',
#   u'zipcode': u'11362'},
#  {u'action': u'Violations were cited in the following area(s).',
#   u'boro': u'BROOKLYN',
#   u'building': u'1114',
#   u'camis': u'50005689',
#   u'critical_flag': u'Critical',
#   u'cuisine_description': u'American ',
#   u'dba': u'BROOKLYN WINE YARD',
#   u'inspection_date': u'2016-01-21T00:00:00.000',
#   u'inspection_type': u'Cycle Inspection / Initial Inspection',
#   u'phone': u'7182503500',
#   u'record_date': u'2016-02-29T06:01:46.000',
#   u'score': u'39',
#   u'street': u'FULTON ST',
#   u'violation_code': u'06D',
#   u'violation_description': u'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.',
#   u'zipcode': u'11238'}]

# %%
import MySQLdb as mdb
import sys

# Setup the database in which we will store the inspection data
def connectDB():
    con = mdb.connect(host = 'localhost', 
                      user = 'root', 
                      passwd = 'dwdstudent2015', 
                      charset = 'utf8', use_unicode=True);
    return con

# %%
def createOpenDB(con, db_name):
    ''' 
    Connects to the database and creates (if it does not exist)
    the database and a time varying and time-invariant table.
    '''
    # Query to create a database
    create_db_query = "CREATE DATABASE IF NOT EXISTS {0} DEFAULT CHARACTER SET 'utf8'".format(db_name)

    # Create a database
    cursor = con.cursor()
    cursor.execute(create_db_query)
    cursor.close()
    pass

    '''This table stores information about the restaurant'''

def createTimeInvariantTable(con, db_name, table_name):
    cursor = con.cursor()
    # Create a table
    # The {0} and {1} are placeholders for the parameters in the format(....) statement
    create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                    (store_id char(15),
                                    store_name varchar(255), 
                                    cuisine_type varchar(255),
                                    borough varchar(255),
                                    phone varchar(255), 
                                    building_number varchar(255),
                                    street varchar(255),
                                    zipcode varchar(255),
                                    PRIMARY KEY(store_id)
                                    )'''.format(db_name, table_name)
    cursor.execute(create_table_query)
    cursor.close()
    
    '''This table stores information about the inspection'''
    
def createTimeVaryingTable(con, db_name, table_name):
    cursor = con.cursor()
    # Create a table
    # The {0} and {1} are placeholders for the parameters in the format(....) statement
    create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                    (store_id char(25),
                                    store_name varchar(250),
                                    inspection_dt datetime,
                                    record_dt datetime,
                                    inspection_type varchar(250),
                                    violation_code varchar(250),
                                    grade varchar(20),
                                    PRIMARY KEY(store_id, inspection_dt, violation_code)
                                    )'''.format(db_name, table_name)
    cursor.execute(create_table_query)
    cursor.close()

con = connectDB()
db_name = 'OpenData'
createOpenDB(con, db_name)
station_table = 'store_info'
createTimeInvariantTable(con, db_name, station_table)
station_table = 'inspection_info'
createTimeVaryingTable(con, db_name, station_table)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: Warning: Can't create database 'OpenData'; database exists
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:32: Warning: Table 'store_info' already exists
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:51: Warning: Table 'inspection_info' already exists

# %%
# Go over the inspection data and store the time-invariant data into the time-invariant data table
def insertStation(con, db_name, table_name, store_id, store_name, cuisine, borough, phone, building_number, street, zipcode):
    db_name = 'OpenData'
    table_name = 'store_info'
    
    query_template = '''INSERT IGNORE INTO {0}.{1}(store_id,
                                    store_name, 
                                    cuisine_type,
                                    borough,
                                    phone, 
                                    building_number,
                                    street,
                                    zipcode)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s)'''.format(db_name, table_name)

    cursor = con.cursor()
    query_parameters = (store_id, store_name, cuisine, borough, phone, building_number, street, zipcode)
    cursor.execute(query_template, query_parameters)
    cursor.close()
    return

def storeTimeInvariantData(con, open_data):

    db_name = 'OpenData'
    table_name = 'store_info'
    
    for x in open_data:
        store_id = x["camis"]
        try:
            store_name = x["dba"]
        except KeyError:
            pass
        cuisine = x["cuisine_description"]
        borough = x["boro"]
        phone = x["phone"]
        building_number = x["building"]
        street = x["street"]
        zipcode = x["zipcode"]
        insertStation(con, db_name, table_name, store_id, store_name, cuisine, borough, phone, building_number, street, zipcode)
        
        print "Inserted", store_name
    # Writes the data in the database, for sure
    con.commit()
    return
 


storeTimeInvariantData(con, store_data)
# Out:
# Inserted MCDONALD'S
# Inserted EASTERN BLOC
# Inserted WESTSIDE BREWHOUSE
# Inserted CAS' WEST INDIAN & AMERICAN RESTAURANT
# Inserted THE RUM HOUSE
# Inserted HAPPY STAR BAKERY
# Inserted LA MEDITERRANEE RESTAURANT
# Inserted YONG SHENG RESTAURANT
# Inserted VERLAINE
# Inserted EDDIE'S DELI & PIZZA
# Inserted THE KENT ALE HOUSE
# Inserted GREENSTREETS SALADS
# Inserted KIKOO SUSHI
# Inserted HECHO EN DUMBO
# Inserted RIVERDALE STEAK HOUSE
# Inserted WO HOP CITY
# Inserted DAE DONG MANOR
# Inserted SMORGAS CHEF/ CREPES DU NORD
# Inserted LIONS BEER STORE
# Inserted CAFE SHIRIN
# Inserted FORT HAMILTON DINER
# Inserted GLATT ALA CARTE
# Inserted CAESAR'S PALACE
# Inserted EL TAPATIO MEXICAN RESTAURANT
# Inserted TROPICAL 128
# Inserted LUNA
# Inserted SHINOBI RAMEN
# Inserted AKI SUSHI
# Inserted EL RICO TINTO BAKERY
# Inserted TASTY FAST FOOD
# Inserted ROSE BENGAL
# Inserted BONAO BAR AND GRILL
# Inserted SYCAMORE
# Inserted SHARMEL CATERERS
# Inserted JUNIPER
# Inserted MIGHTY QUINN'S BBQ
# Inserted SUGAZ BAR
# Inserted OLI 99¢ FRESH PIZZA
# Inserted MAMA'S FRIED CHICKEN
# Inserted MI TACO SANTANA
# Inserted EL TAPATIO MEXICAN RESTAURANT
# Inserted THE FIFTH ESTATE
# Inserted BEDFORD PIZZA CAFE
# Inserted MEXI JOE'S GRILL
# Inserted TACO BELL
# Inserted MASTER EXPRESS DELI & RESTAURANT
# Inserted LA MONEDA RESTAURANT
# Inserted TROOST
# Inserted KARMA RESTAURANT
# Inserted PARAISO ZONA VIP RESTAURANT BAR
# Inserted LUZ DE AMERICA RESTAURANT
# Inserted ROCK BAR
# Inserted WYTHE DINER/ LA ESQUINA
# Inserted JOSEPH LEONARD
# Inserted EL ANZUELO FINO RESTAURANT
# Inserted NEW KIM'S RESTAURANT
# Inserted MCDONALD'S
# Inserted REX CHELSEA
# Inserted THE CANNIBAL
# Inserted DIECI
# Inserted THE CITY BAKERY
# Inserted TUNG THONG THAI RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted ILILI RESTAURANT
# Inserted MADIBA
# Inserted HOT SICHUAN
# Inserted ISLAND SOFT PRETZEL STOP
# Inserted OH TAISHO
# Inserted THE STANDARD
# Inserted VACCARO'S PIZZERIA & TRATTORIA
# Inserted WINDFALL
# Inserted THOMASINA'S CATERING HALL
# Inserted PIO HOT BAGELS
# Inserted WTF COFFEE & TEA
# Inserted MANGOS PARADISE SMOOTHIE
# Inserted NEW TIMES CHINESE RESTAURANT
# Inserted MR. WONTON
# Inserted CHUCK E. CHEESE'S
# Inserted CORONA PIZZA
# Inserted CROWN DINER
# Inserted 9 & 8 CAFE
# Inserted MCDONALD'S
# Inserted TUCK SHOP
# Inserted STROMBOLI PIZZA
# Inserted ZUCKER'S BAGEL
# Inserted 9TH AVE SALOON
# Inserted LOS CUENCANITOS
# Inserted HUNTER'S
# Inserted SATI'S ROTI SHOP
# Inserted CARVEL ICE CREAM
# Inserted EL NUEVO ATLANTIC LOUNGE
# Inserted TORO
# Inserted XES LOUNGE
# Inserted CHINA KITCHEN
# Inserted 121 FULTON STREET
# Inserted 211 NEW TACO GRILL
# Inserted TACO KING
# Inserted YI ZHANG FISHBALL
# Inserted KARLOFF
# Inserted THE ABBEY
# Inserted STANTON SOCIAL
# Inserted RED VELVET HOOKAH LOUNGE
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted MIKE'S PUB
# Inserted LIN'S NO 1 CHINESE RESTAURANT
# Inserted KYOTO SUSHI V
# Inserted THE 5 AND DIAMOND
# Inserted OSAKA JAPANESE FUSION
# Inserted LUIGI PIZZERIA & RISTORANTE
# Inserted KUNG FU XIAO LONG BAO
# Inserted ROASTOWN
# Inserted DIAMOND KRUST
# Inserted PARRILLA LATINA
# Inserted BARNES & NOBLE CAFE
# Inserted IL TOSCANO RISTORANTE
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted RED STIXS
# Inserted RAVAGH PERSIAN GRILL
# Inserted CAFE 75 BAR
# Inserted KITARO
# Inserted TOMMY PIZZERIA
# Inserted LULU & PO
# Inserted CHO-SEN GARDEN
# Inserted SUNSET DINER
# Inserted GP SMOOTHIES & GIFTSHOP
# Inserted PIZZA PLUS
# Inserted CAFE RESTAURANT
# Inserted EL NUEVO YAUCO RESTAURANT
# Inserted LITTLE BROWN JUG
# Inserted Manon Cafe / Leonidas
# Inserted ZEFES MEXICAN RESTAURANT
# Inserted TABARE
# Inserted A & S CATERERS
# Inserted HIMALAYAN YAK RESTAURANT
# Inserted WOOPS! BAKESHOP
# Inserted EL HORNERO BAKERY
# Inserted (LEWIS DRUG STORE) LOCANDA VINI E OLII
# Inserted THAI TONY'S
# Inserted RECETTE
# Inserted EL GRAN VALLE II
# Inserted HILTON HOTEL JFK AIRPORT
# Inserted BELLA VITA
# Inserted PIZZA BEACH
# Inserted KLIMAT
# Inserted 101 RESTAURANT AND BAR
# Inserted DELTA SKY CLUB (BARTENDER SERVICE TERMINAL D DELTA DEPARTURE)
# Inserted SCALETTA RISTORANTE
# Inserted PUBLIC RESTAURANT/THE DAILY
# Inserted EAST SEAFOOD RESTAURANT
# Inserted EL GIRASOL BAKERY
# Inserted SARAGHINA
# Inserted PICK-A-BAGEL
# Inserted Bar B
# Inserted L AND Z BAKERY
# Inserted PINCHE TAQUIERA
# Inserted MEDINA FRIED CHICKEN & INDIAN CUISINE
# Inserted MCDONALD'S
# Inserted CAFE DUKE
# Inserted MATCH 65
# Inserted CHEF YU / AZUKI
# Inserted CRUMBS BAKE SHOP
# Inserted TONIC EAST
# Inserted ROADHOUSE RESTAURANT
# Inserted BHATTI INDIAN GRILL
# Inserted IRIS TEA & BAKERY, QUICKLY
# Inserted HAPPY SU GARDEN
# Inserted MC ANN'S
# Inserted STARBUCKS
# Inserted THE PINK TEA CUP
# Inserted SUBWAY
# Inserted DC KTV
# Inserted CROXLEYS THE ABBEY
# Inserted FISHERMAN'S COVE
# Inserted SIMIT AND SMITH
# Inserted PANCHITO'S
# Inserted DOMINO'S
# Inserted BLACK SEED BAGELS
# Inserted 652 LIN'S GARDEN
# Inserted POLLOS MARIO
# Inserted PICK & PAY GYRO & PIZZA
# Inserted EL MAGUEY Y LA TUNA
# Inserted Patea
# Inserted SNACKS-N-WHEELS
# Inserted NEW YORKER HOTEL KITCHEN
# Inserted DON COGUI
# Inserted NORTHERN SUSHI
# Inserted LA RIVISTA RESTAURANT
# Inserted LA VIE
# Inserted FPB  BAKERY
# Inserted MASHA LI/TIAN SHANG REN JIAN BAR
# Inserted HUNTER'S
# Inserted TRADICIONES LATINAS RESTAURANT
# Inserted CROWN GOURMET DELI
# Inserted PIZZA HUT
# Inserted AL'S DELI
# Inserted TACO BELL
# Inserted CHIFLEZ
# Inserted UNCLE'S FRIED CHICKEN
# Inserted SHIH LEE CHINESE GOODEATS
# Inserted FRITZIES BAKE SHOP
# Inserted KAT'S ISLAND CUISINE
# Inserted STATEN ISLAND DINER
# Inserted DILEO'S PIZZERIA
# Inserted PLAZA FOOD COURT
# Inserted WENDY'S
# Inserted SUBWAY
# Inserted MOM'S BAKERY
# Inserted JUQUILITA BAR
# Inserted GRAND SICHUAN
# Inserted BAGEL LAND
# Inserted COCORON
# Inserted JOHN'S DELI
# Inserted MEENA HOUSE CAFE
# Inserted FASTWAY RESTAURANT
# Inserted TASTY BITES
# Inserted HILLSIDE HOT BAGELS
# Inserted PADDY'S REILLY'S BAR
# Inserted WING HING SEAFOOD RESTAURANT
# Inserted CASCABEL TAQUERIA
# Inserted CAFE OMAR/PATTY PALACE
# Inserted LA PENTOLA ITALIAN PIZZERIA
# Inserted TERRA
# Inserted BRANCH OFC
# Inserted DOMAINE WINE BAR
# Inserted RADIANCE
# Inserted HARLEM TAVERN
# Inserted RICHIE RICH CARIBBEAN TASTE II
# Inserted AH ZHONG FOOD STORE # 5
# Inserted CARVEL ICE CREAM
# Inserted FIVE GUYS FAMOUS BURGERS AND FRIES
# Inserted GOURMET 45
# Inserted WILLIAMSBURG PIZZA
# Inserted NEW GARDEN
# Inserted IHOP
# Inserted DUNKIN' DONUTS
# Inserted CANOA
# Inserted WILLIAM HALLET
# Inserted PAPAYA DOG 42ND ST
# Inserted LIBERTY CATERING
# Inserted DEUX AMIS
# Inserted LOS TRES POTRILLOS RESTAURANT
# Inserted TRATTORIA L'INCONTRO
# Inserted YONAH SHIMMELS KNISHES
# Inserted RALPH'S ICES
# Inserted NEW ARPING RESTAURANT
# Inserted DEL CORSO PIZZERIA
# Inserted CROWN FRIED CHICKEN
# Inserted EL REY DE LA CARIDAD
# Inserted Lan Zhou Handmade Noodle
# Inserted MAJA'S TAPAS RESTAURANT BAR
# Inserted CHU'S GOURMET
# Inserted OH TAISHO
# Inserted SUN SAI GAI RESTAURANT
# Inserted VISTA HERMOSA DELI RESTAURANT
# Inserted HAPPY SU GARDEN
# Inserted PAPA JOHN'S
# Inserted CAFE RUBIO
# Inserted NEW SOUL CAFE
# Inserted FAY DA BAKERY
# Inserted CECI RESTAURANT
# Inserted BLUE GINGER
# Inserted EL MANGU SABROSO RESTAURANT
# Inserted ARCHWAY CAFE (unit 114) on PEARL ST
# Inserted THE LONG ROOM
# Inserted LA ISLA CAFE RESTAURANT
# Inserted PINE RESTAURANT
# Inserted KING HOUSE RESTAURANT
# Inserted SEVEN TURKISH GRILL
# Inserted CEBU
# Inserted JOYA
# Inserted LITTLE ITALY PIZZA
# Inserted L' CHAIM CAFE
# Inserted DOMINO'S
# Inserted EL NUEVO SABOR LATINO
# Inserted NANCY'S RESTAURANT
# Inserted HUNAN DELIGHT
# Inserted NO 7 NORTH
# Inserted BELLA NAPOLI
# Inserted ZAMAAN HOOKAH BAR
# Inserted SAN PIETRO
# Inserted OAXACA TAQUERIA
# Inserted DUNKIN' DONUTS
# Inserted BENTON CAFE
# Inserted JUQUILITA BAR
# Inserted BOSSA NOVA CIVIC CLUB
# Inserted C & L BAKERY
# Inserted RAKU II ITS JAPANESE
# Inserted TACOMBI AT FONDA NOLITA
# Inserted K ONE BUFFET
# Inserted NOSH! - COURTYARD BY MARRIOTT
# Inserted GORDON BENNETT
# Inserted MILL BASIN BAGEL CAFE
# Inserted SAW SHACK
# Inserted OMONIA NEXT DOOR
# Inserted THE KING OF EMPANADAS
# Inserted KABIRS BAKERY
# Inserted HIDE CHAN RAMEN
# Inserted EAT & GO ISTANBUL/NEW YORK
# Inserted LUCKY PIZZA
# Inserted YET-NAL JJAJANG
# Inserted CARVEL ICE CREAM
# Inserted IT'Z ALL 4 U
# Inserted WEST 53RD GOURMET DELI
# Inserted 5 STAR CHEESE STEAK AND PIZZA
# Inserted PLANET WINGS
# Inserted EL VALLE RESTAURANT
# Inserted LE BASKET
# Inserted CHEN'S GARDEN
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted PAPA JOHN'S
# Inserted MERCY COLLEGE
# Inserted TACO Y MAS
# Inserted WAZA SUSHI
# Inserted BANGAL CURRY
# Inserted ALEX LUNCHEONETTE
# Inserted SZECHUAN PALACE
# Inserted FASHION INSTITUTE OF TECHNOLOGY DAVID DUBINSKY STUDENT CENTER
# Inserted HAPPY STAR BAKERY
# Inserted PETER LUGER STEAKHOUSE
# Inserted SUBWAY
# Inserted COURT STREET BAGELS
# Inserted PONCHE TAQUERIA
# Inserted RED SPOON
# Inserted EL NUEVO SABOR LATINO
# Inserted NEW CHINA STAR
# Inserted THIS & THAT
# Inserted OMEN JAPANESE CUISINE
# Inserted ROLL-N-ROASTER
# Inserted EVERGREEN RESTAURANT
# Inserted J & JOE DELI & GROCERY
# Inserted LA PARADA RESTAURANT
# Inserted COLLEGE POINT MULTIPLEX CINEMAS
# Inserted EL RUMBERO BAR RESTAURANT
# Inserted BROTHER JIMMY'S BBQ
# Inserted JOEY PEPPERONI'S PIZZA
# Inserted TABARE
# Inserted EL CONQUISTADOR RESTAURANT
# Inserted ODRADEKS COFFEE HOUSE
# Inserted FONDA
# Inserted PIER 79/NY WATERWAY SEATTLE CAFE
# Inserted KREYOL FLAVOR
# Inserted GOODY'S SPANISH FOOD
# Inserted TIELLA RESTAURANT
# Inserted THE BUTHCHER'S DAUGHTER MARKET
# Inserted LEA
# Inserted MURPHY'S TAVERN
# Inserted BAGELS N GREENS
# Inserted BLARNEY CASTLE
# Inserted PREVITI PIZZA
# Inserted MAX
# Inserted SAM'S
# Inserted HILLSIDE GOURMET
# Inserted TEXAS STAR SNACK BAR
# Inserted WHISKEY TOWN
# Inserted NEW RED FLOWER CHINESE RESTAURANT
# Inserted MICHAEL & SONS ITALIAN FOOD & PIZZA
# Inserted SOFIA PIZZA RESTAURANT
# Inserted WENG'S PALACE
# Inserted DUNKIN' DONUTS
# Inserted POMODORI
# Inserted CUE BAR
# Inserted EASTERN OCEAN CHINA KING RESTAURANT
# Inserted NEW CORNER
# Inserted LEE'S TAVERN
# Inserted THE MANHATTAN AT TIMES SQUARE
# Inserted ANYWAY CAFE BAR
# Inserted THE COMMONS CHELSEA
# Inserted MCDONALD'S
# Inserted THE VILLAGE LANTERN
# Inserted BILLIARD COMPANY
# Inserted METRO CAFE
# Inserted SHERWOODS KEEP
# Inserted SOL DE QUITO RESTAURANT
# Inserted THE CREEK AND THE CAVE
# Inserted AUNT BUTCHIES CAFE
# Inserted DOUBLE DRAGON RESTAURANT
# Inserted PETE'S CAFE
# Inserted EL GRAN CANARIO RESTAURANT
# Inserted CHINA KING
# Inserted HEAVENLY MIRACLE ACADEMY DAY CARE CENTER
# Inserted DOWNTOWN BAKERY II MEXICAN FOOD
# Inserted FOOD LIN
# Inserted GLEESON'S SPORTS BAR
# Inserted THE DART INN
# Inserted GINGER'S BAR
# Inserted BLAKE AND TODD
# Inserted CARIDAD CHINA RESTAURANT
# Inserted IL FORNO OF BROOKLYN
# Inserted DANTE'S GOURMET FOOD
# Inserted BOWLMOR CHELSEA PIERS
# Inserted LECHONERA TROPICAL & GRILL
# Inserted CHIMU
# Inserted EL CASTILLO DEL POLLO COFFEE SHOP
# Inserted ORIGINAL SANDWICHES
# Inserted PICANTERIA EL AUSTRO
# Inserted OCEAN GRILL
# Inserted CITI BAGEL & DELI
# Inserted TUTTI MATTI
# Inserted LA ABUNDANCIA BAKERY
# Inserted TANDOOR PALACE
# Inserted YUMMY SZECHUAN HOUSE
# Inserted ALMAR
# Inserted WEST CARIBBEAN INTERNATIONAL RESTAURANT
# Inserted SUBWAY
# Inserted LA BELLA PIZZA
# Inserted 739 FRANKLIN BAR & LOUNGE
# Inserted LA SABROSURA
# Inserted GREAT WALL RESTAURANT
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted CATALDO'S RESTAURANT
# Inserted RAMEN THUKPA
# Inserted PARIS BLUES
# Inserted TOTTO RAMEN
# Inserted SWINE
# Inserted GABRIELLA CAFE
# Inserted CHINA TASTE
# Inserted SMILE TO GO
# Inserted KAT'S TASTY GRILL
# Inserted PAPA JOHN'S
# Inserted 55 BAR
# Inserted NY DC CAFE
# Inserted NANCY WHISKEY PUB
# Inserted AH! CHIHUAHUA
# Inserted DUNKIN' DONUTS
# Inserted LA NORTENA
# Inserted LA CASA BELLA
# Inserted OLLA WINE BAR
# Inserted FUJI BAKERY
# Inserted FULTON CAFE
# Inserted SHOPSINS GENERAL STORE (STORE #16)
# Inserted RJC FAMILY'S CAFE
# Inserted BOOM BOOM ROOM, LE BAIN, THE STANDARD
# Inserted NANA RESTAURANT & BAR
# Inserted Central Station
# Inserted TINA'S RESTAURANT
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted T.G.I. FRIDAY'S
# Inserted TRATTORIA PESCE PASTA
# Inserted MUCHMORE'S
# Inserted LENNY'S PIZZA
# Inserted KAFFE 1668
# Inserted MERIT KABAB PALACE
# Inserted TAZZA
# Inserted NEW ASIAN RESTAURANT
# Inserted MMM THATS A WRAP
# Inserted RUBI ROSA RESTAURANT & BAR
# Inserted 12 CORNERS
# Inserted EL GRAN MALECON RESTAURANT
# Inserted BELLA NAPOLI
# Inserted PIORA
# Inserted VANESSA'S DUMPLING HOUSE
# Inserted 456 RESTAURANT
# Inserted SALTY DOG RESTAURANT
# Inserted IGNAZIO'S
# Inserted CIPRIANI 42ND STREET
# Inserted JAMBA JUICE
# Inserted PRONTO RESTAURANT
# Inserted STAND 139 TACO FRITES
# Inserted GINGER
# Inserted ISLAND BLEND JUICE  BAR .
# Inserted ERAWAN THAI CUISINE
# Inserted JOHN'S FRIED CHICKEN
# Inserted O'S GRILL SPOT
# Inserted BLACK IRIS MIDDLE EASTERN CUISINE
# Inserted MOZZARELLA & VINO
# Inserted CASTILLO ECUATORIANO RESTAURANT
# Inserted CHEETAHS GENTLEMENS CLUB & RESTAURANT
# Inserted ST. ALBANS PIZZERIA
# Inserted PARADISO NY
# Inserted STARBUCKS
# Inserted AVE NIDA
# Inserted SIGIRI
# Inserted MAXIM CHINESE RESTAURANT
# Inserted EL NUEVO JB BAKERY
# Inserted SUBWAY
# Inserted CHOPSTIX
# Inserted PITKIN BONAO GRILL RESTAURANT
# Inserted S & S HOT SPOT ROTI SHOP & RESTAURANT
# Inserted AUDREY'S CONCERTO
# Inserted ZUTTO
# Inserted MANNY'S ON SECOND
# Inserted SWEET & VICIOUS
# Inserted ROMANIAN GARDEN
# Inserted SOLDIERS CARIBBEAN RESTAURANT
# Inserted PLENTY CAFE BAKERY CATERING
# Inserted PACIFICANA REST
# Inserted THE SQUEEZE
# Inserted LA GUADALUPANA RESTAURANT
# Inserted THE RAGING SKILLET
# Inserted WOK WOK RESTAURANT
# Inserted MADDY'S
# Inserted IMPERIAL PALACE
# Inserted GREENWICH VILLAGE BISTRO
# Inserted HILTON GARDEN INN
# Inserted ARTHUR'S TAVERN
# Inserted BERGER'S ON THE GO
# Inserted CAFE BORA BORA
# Inserted BAREBURGER
# Inserted RAINES LAW ROOM
# Inserted DOMINO'S
# Inserted EASTERN OCEAN ONE
# Inserted LUCKY ZHANG'S FAMILY
# Inserted JIAN ON CHINESE RESTAURANT
# Inserted LE PAIN QUOTIDIEN
# Inserted COLUMBUS FLAME
# Inserted SALUD SOHO
# Inserted YAMATO JAPANESE CUISINE
# Inserted SOUTH'S
# Inserted LA CUARTA RESTAURANT
# Inserted PADO SUSHI
# Inserted MONTE LIMAR SPORT BAR LOUNGE
# Inserted GIORGIONE
# Inserted KRISPY PIZZERIA
# Inserted GOURMET GRILL
# Inserted DA NICO RESTAURANT
# Inserted HOP KEE RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted CHEN'S GARDEN
# Inserted JAMAO COFFEE SHOP RESTAURANT
# Inserted WHITMAN & BLOOM
# Inserted Pick-A-Bagel
# Inserted TOTTENVILLE BAGELS
# Inserted AMY'S BREAD
# Inserted DRINK
# Inserted BIJAN'S
# Inserted METROPOLITAN CLUB
# Inserted MIA
# Inserted RESTAURANTE & PANADERIA GUATELINDA
# Inserted THE BEEKMAN
# Inserted THE RAIL LINE DINER
# Inserted PAZZA NOTTE
# Inserted SCHNIPPERS
# Inserted DEUTSCHE BANK CONFERENCE CENTER
# Inserted CAFE HABANA/CAFE HABANA TO GO
# Inserted EDDIE FANCY FOOD
# Inserted NEEROB
# Inserted LAS AMERICAS BAKERY
# Inserted MS. DAHLIA'S CAFE
# Inserted THE MAD DONKEY
# Inserted DUNKIN' DONUTS
# Inserted THE HEIGHTS BAR & GRILL
# Inserted CARRERA BAKERY
# Inserted MAITE
# Inserted MCDONALD AVENUE DINER
# Inserted PORTO BELLO PIZZERIA & RESTAURANT
# Inserted BACK HOME BAKERY
# Inserted OLIVE TREE
# Inserted FREDDY'S PIZZA
# Inserted TAVERN ON THE THIRD
# Inserted CAVALA
# Inserted THE STANDING ROOM
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted LORELEY RESTAURANT
# Inserted CHINESE FOOD RESTAURANT
# Inserted EASY CORNER RESTAURANT & GRILL
# Inserted FRAME GOURMET EATERY
# Inserted KFC
# Inserted GALLI RESTAURANT
# Inserted DOUBLE HAPPY RESTAURANT
# Inserted THE CAKE CHEF
# Inserted C J's BAR & LOUNGE
# Inserted RED STAR sandwich shop
# Inserted MING WONG RESTAURANT
# Inserted WB CARIBBEAN RESTAURANT
# Inserted BOAT HOUSE & CAJUN CUISINE
# Inserted FRANKS PIZZA
# Inserted vapor lounge
# Inserted RED APPLE
# Inserted FELIDIA RESTAURANT
# Inserted VINA DEL MAR RESTAURANT
# Inserted CITY LINE PIZZA & PASTA
# Inserted FRANK'S PIZZA RESTAURANT
# Inserted NEW ANDY'S DELI
# Inserted JIMBO'S HAMBURGER PALACE
# Inserted NERAI
# Inserted D'BLASS RESTAURANT
# Inserted RED MANGO
# Inserted LAS AMERICAS BAKERY
# Inserted GOOD WOK CHINESE RESTAURANT
# Inserted STARBUCKS
# Inserted THE SAINT CATHERINE
# Inserted RED MANGO
# Inserted PEACHWAVE FROZEN YOGURT
# Inserted JUICE GENERATION
# Inserted GREAT N.Y. NOODLETOWN
# Inserted PIZZA BELLA
# Inserted CROSS BRONX PIZZERIA
# Inserted FU HAI RESTAURANT
# Inserted GINO'S PIZZERIA
# Inserted BUTTERFIELD CATERING
# Inserted BIRDBATH
# Inserted RAMEN-YA
# Inserted KENNEDY FRIED CHICKEN
# Inserted HALLAL SANDWICH SHOP
# Inserted LITTLE ITALY PIZZA/PAPAYA DOG
# Inserted HO YIP RESTAURANT
# Inserted ALL'ONDA
# Inserted JUNGLE CAFE
# Inserted CAFFE E VINO
# Inserted BEN'S PIZZA
# Inserted BLACK TREE
# Inserted NEW JADE HOUSE
# Inserted GOLDEN PLACE
# Inserted CAFE METRO
# Inserted DRAM SHOP
# Inserted VICTOR'S CAFE
# Inserted VILLAGE MARIA PIZZA II
# Inserted TWO BOOTS
# Inserted CULTURE 36
# Inserted HAAGEN-DAZS
# Inserted LA MIA PIZZA
# Inserted Bagel Bistro & Diner
# Inserted CASA MEZCAL
# Inserted PARIS BAGUETTE
# Inserted THE CORNELL CENTER OF NEW YORK
# Inserted CLOUD 9
# Inserted CHINA RED GOURMENT
# Inserted OLLIES 42ND
# Inserted CAFE RUBIO
# Inserted LA DOLCE ITALIA BAKERY
# Inserted MOJITO CUBAN CUISINE
# Inserted FISHERMAN'S COVE
# Inserted HAAGEN-DAZS
# Inserted EL FAMILAR RESTAURANT
# Inserted JIN RAMEN
# Inserted THE LUTHERAN HALAL CAFE
# Inserted STARBUCKS
# Inserted HOP LEE RESTARANT
# Inserted SING SING KARAOKE
# Inserted J & C DELICIAS
# Inserted ISAACS COFFEE SHOP
# Inserted JAMEX SPORTS BAR
# Inserted STONE STREET COFFEE COMPANY
# Inserted BHUTANESE EMA DATSI RESTAURANT
# Inserted EL CHICANITO RESTAURANT BAR
# Inserted LA GITANA PANADERIA - RESTAURANTE
# Inserted TACOS MEXICO
# Inserted NEW DRAGON TOWN OF MANHATTAN
# Inserted HALE & HEARTY SOUP
# Inserted 86 BAKERY
# Inserted HUSH CAFE LOUNGE & GARDEN
# Inserted THOMASINA'S CATERING HALL
# Inserted LA GATA GOLOSA
# Inserted DO HWA
# Inserted HAVANA CAFE (SECTION 10)
# Inserted B.B. KINGS
# Inserted ZEFF'S PIZZERIA
# Inserted LEE'S KITCHEN
# Inserted HOP LEE KITCHEN
# Inserted LARK
# Inserted FOOTPRINTS CAFE EXPRESS
# Inserted A TASTE OF SHANGHAI RESTAURANT
# Inserted CITI EMPLOYEE CAFETERIA
# Inserted MOE'S SOUTHWEST GRILL
# Inserted SOLACE BAR & GRILL
# Inserted QUEEN BAKERY II
# Inserted AMANECER LATINO RESTAURANT
# Inserted NONNA'S OLD FASHIONED PIZZERIA / NONNA'S BAGELS
# Inserted CRIME SCENE
# Inserted HADJA MARLEY RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted CITY COLLEGE CAFETERIA
# Inserted TROYKA/DA MIKELLE PALACE/MIKELLE CORNER/SUSHI & STEAK HOUSE
# Inserted KAT'S ISLAND CUISINE
# Inserted MUI KITCHEN & BAR
# Inserted ZAGARA WINE BAR
# Inserted TSION CAFE & BAKERY
# Inserted BREADZONE
# Inserted MI PALENQUE
# Inserted PLANET WINGS
# Inserted ABC KITCHEN
# Inserted THIS & THAT
# Inserted COURT STREET GROCERS
# Inserted BEN & JERRY'S
# Inserted BASURERO
# Inserted FRESCO BAR CAFE RESTAURANT
# Inserted MOE'S CAFE
# Inserted MONTEZUMA RESTAURANT
# Inserted BONCHON
# Inserted FIORENTINO RISTORANTE
# Inserted DOMINO'S
# Inserted Campagnola Restaurant
# Inserted LA DINASTIA
# Inserted TONY'S FAMOUS PIZZA
# Inserted CHOCOLAT
# Inserted DREDSURFER GRILL
# Inserted J & R PIZZERIA NO. 2
# Inserted BLEACHERS 67 SPORTS BAR AND GRILL
# Inserted BROTHERS FISH MARKET
# Inserted BAY HOUSE BISTRO
# Inserted NICKS PLACE
# Inserted BLUE RIBBON SUSHI BAR & GRILL
# Inserted MUSIC HALL OF WILLIAMSBURG
# Inserted NEW PUNJAB RESTAURANT & GRILL
# Inserted CORNERSTONE CAFE
# Inserted I & R DELI
# Inserted FRONT STREET PIZZA
# Inserted KENNEDY FRIED CHICKEN
# Inserted HUNAN GLATT KOSHER
# Inserted SIAM ORCHID THAI RESTAURANT
# Inserted MAHAICA HOT SPOT & RESTAURANT
# Inserted WASHINGTON BAGEL CAFE
# Inserted BREAD
# Inserted MACDOUGAL STREET ALE HOUSE
# Inserted MCDONALD'S
# Inserted OXFORD CAFE
# Inserted HANGAR 11 BAR & GRILL
# Inserted ROYAL PIZZA
# Inserted AROMA
# Inserted BROOME STREET BAR
# Inserted GREEN SKY RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted 21 SHANGHAI HOUSE
# Inserted TACO BELL
# Inserted NINOS 46
# Inserted UNO PIZZERIA AND GRILL
# Inserted CHINA PEKING RESTAURANT
# Inserted LOS BALBUENA RESTAURANT
# Inserted SUBWAY
# Inserted INDIGO INDIAN CUISINE
# Inserted JERUSALEM II PIZZA
# Inserted MIKE'S DINER
# Inserted HIGHLINE BALLROOM
# Inserted JR. BELLA'S PIZZA & PASTA 2
# Inserted MURPHY'S LAW
# Inserted MEXICAN RESTAURANT
# Inserted THE PUMP JUICE BAR
# Inserted PONGSRI THAI RESTAURANT
# Inserted HAMPTON INN & SUITES
# Inserted PAPPARDELLA
# Inserted cervecceria Havemeyer
# Inserted HIDE CHAN RAMEN
# Inserted LIC MARKET
# Inserted T.G.I. FRIDAY'S
# Inserted DUNKIN' DONUTS
# Inserted CHARO RESTAURANT
# Inserted LE PADDOCK
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted THE AUSTRALIAN
# Inserted MAMA MIA 44 SW
# Inserted EL REY
# Inserted MADDEN'S PUB
# Inserted 18 STARS KITCHEN
# Inserted LATINO EXPRESS RESTAURANT
# Inserted STAND 213
# Inserted CALIFORNIA PIZZA KITCHEN
# Inserted CARLOS AND GABBY'S CANTINA GRILL
# Inserted HOT JALAPENO RESTAURANT
# Inserted B & M HOT BAGEL & GROCERY
# Inserted KAFF KAFE
# Inserted LAS PANTERAS NEGRAS RESTAURANT
# Inserted TREND DINER
# Inserted LIBERTY DINER
# Inserted NEW TASTE OF CHINA
# Inserted CROWN FRIED CHICKEN
# Inserted BOHEMIAN NEW YORK
# Inserted BLOSSOM DU JOUR
# Inserted STEEL PAN
# Inserted 100 montaditos
# Inserted EL REY DE LA CARIDAD
# Inserted BLOSSOM DU JOUR
# Inserted VIA QUADRONNO
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted SARILING ATIN
# Inserted RISTORANTE LUNA
# Inserted WILD GINGER VEGAN CAFE
# Inserted BUKHARA GRILL
# Inserted GREEN TOMATO
# Inserted WONDERFUL RESTAURANT
# Inserted BRISAS DEL MAR SEAFOOD MARKET
# Inserted KING DRAGON
# Inserted COSTA BRAVA RESTAURANT
# Inserted L AND Z BAKERY
# Inserted KAFENEO
# Inserted S & J KITCHEN
# Inserted BED-STUY FISH FRY
# Inserted SUGAZ BAR
# Inserted YOURS & MINE RESTAURANT
# Inserted BAGEL CLUB
# Inserted FLATIRON LOUNGE
# Inserted RED FLAME DINER
# Inserted BETTOLONA
# Inserted AKWAABA RESTAURANT
# Inserted RICO CHIMI
# Inserted HOT BAR COLD BAR
# Inserted MARIO'S PIZZERIA
# Inserted Greenforce Juice
# Inserted YU SUSHI
# Inserted NEW KABAB DINER
# Inserted THE THREE MONKEYS
# Inserted NEW GREAT TASTE RESTAURANT
# Inserted GEO SI GI
# Inserted CANCUN MEXICAN RESTAURANT
# Inserted YUMMY DIM SUM
# Inserted MOFONGO DEL VALLE
# Inserted LA GUARIDA BAR
# Inserted LATINO RESTAURANT
# Inserted VILLAGE NATURAL
# Inserted QUALITY FOOD CHINESE KITCHEN
# Inserted 2 BROS PIZZA
# Inserted RITZ BAR
# Inserted GRANDAISY BAKERY
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted CEMITAS PUEBLA RESTAURANT
# Inserted AMURA JAPANESE RESTAURANT
# Inserted GO-GO'S DELI & CONVENIENCE
# Inserted RIBALTA
# Inserted THE COFFEE BEAN & TEA LEAF
# Inserted TEAFFEE
# Inserted TONE AUTHENTIC GEORGIAN BAKERY & CUISINE
# Inserted BAGELICIOUS
# Inserted ANKA GRILL
# Inserted DOMINO'S
# Inserted ANTOJITOS DELI FOOD
# Inserted SARGE'S
# Inserted HONK KONG BOY RESTAURANT
# Inserted NEW CHINA DELIGHT
# Inserted MOMOFUKU MILK BAR UWS
# Inserted TAL BAGELS
# Inserted PATES PLUS BAKERY
# Inserted YOOGLERS FROZEN YOGURT
# Inserted MAISON KAYSER
# Inserted BRISAS DEL MAR RESTAURANT
# Inserted BED-STUY FISH FRY
# Inserted APERITIVO PIZZA BAR
# Inserted TRANQUILITY BAR & LOUNGE
# Inserted BASSANOVA RAMEN
# Inserted LUKE'S PIZZA
# Inserted PRET A MANGER
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted TRUFA RESTAURANT
# Inserted DESMOND'S TAVERN
# Inserted FAMOUS AMADEUS PIZZA
# Inserted Brickhouse Pizzeria
# Inserted CHO-SEN GARDEN
# Inserted MARIO'S PIZZERIA
# Inserted LA CARRETA RESTAURANT
# Inserted DRAGON CITY
# Inserted PAPA JOHN'S
# Inserted JOE'S CRAB SHACK
# Inserted THE PIT AT PEOPLES IMPROV THEATER
# Inserted MOONSTRUCK DINER
# Inserted ISLAND GROVE RESTAURANT
# Inserted HURON CLUB/SOHO PLAYHOUSE
# Inserted SZECHUAN KITCHEN
# Inserted THE ROCK SHOP
# Inserted VIA QUADRONNO
# Inserted NEWTOWN
# Inserted BIG WONG RESTAURANT
# Inserted ST MAZIE
# Inserted CHINANTLA RESTAURANT
# Inserted MI BELLA DAMA RESTAURANT
# Inserted PIAXTLA ES MEXICO DELI
# Inserted XING HUI LINDA KITCHEN
# Inserted TRATTORIA L'INCONTRO
# Inserted HIBISCUS RESTAURANT
# Inserted DRAGON STAR
# Inserted NUEVA ESPERANZA
# Inserted GUAYACO FOOD & ROLLAS
# Inserted DEAN STREET
# Inserted BREAK BAR & BILLARDS
# Inserted WENDY'S
# Inserted CHINA MOON CHINESE RESTAURANT
# Inserted CIAO FOR NOW
# Inserted GARDEN OF EAT-IN
# Inserted YUMMY CHINESE KITCHEN
# Inserted EL JAYA RESTAURANT
# Inserted NEW TRADITIONS
# Inserted MIKE'S ISLAND GRILL RESTAURANT
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted Big E's Deli
# Inserted MI SABOR CAFE
# Inserted PIAXTLA ES MEXICO DELI
# Inserted RICHI RICH PALACE
# Inserted SUBWAY
# Inserted LIN LONG XUAN RESTAURANT INC
# Inserted COLLADO RESTAURANT
# Inserted THUNDER JACKSONS URBAN ROADHOUSE
# Inserted CAFE PRAGUE
# Inserted QUARTINO BOTTEGA ORGANICA
# Inserted THAI ELEPHANT RESTAURANT
# Inserted AL CHOLO BAKERY
# Inserted REPUBLIC RESTAURANT
# Inserted YEE LI RESTAURANT
# Inserted TWIN DONUTS
# Inserted SNACK BAR
# Inserted JP'S WATERSIDE RESTAURANT
# Inserted WINE BAR & RISTORANTE
# Inserted SAHARA ARK
# Inserted PIANOS
# Inserted LUCKY ZHANG'S FAMILY
# Inserted SMASHBURGER
# Inserted tutto il giorno
# Inserted BALCON QUITENO RESTAURANT
# Inserted SIK GAEK
# Inserted JAZZY WEST INDIAN AND AMERICAN RESTAURANT
# Inserted BOBBY VAN'S
# Inserted JIREH RESTAURANT
# Inserted MERCURY BAR
# Inserted NAPOLEON'S SOUTHERN CUISINE & BAKERY
# Inserted TERESA'S GOURMET
# Inserted MIKE'S UNICORN DINER
# Inserted BREWSKI'S BAR & GRILL
# Inserted SUBWAY
# Inserted BREWSKI'S BAR & GRILL
# Inserted THE LIGHTS OF BAKU
# Inserted PASTICCERIA LA TORRE
# Inserted CAFFE BENE
# Inserted STAR CAFE
# Inserted AUREOLE
# Inserted HOTEL CHANTELLE
# Inserted ANGELOS DELI RESTAURANT
# Inserted GIRALDA BAKERY
# Inserted HANG LEE RESTAURANT
# Inserted TRATTORIA 35
# Inserted 3 BROTHERS TURKISH FOOD MARKET
# Inserted DOMINO'S
# Inserted CLADDAGH INN
# Inserted FLUTE
# Inserted THE AVENUE
# Inserted DUNKIN' DONUTS
# Inserted CARLOS & GABBY'S
# Inserted OTARIAN
# Inserted TULCINGO RESTAURANT
# Inserted GREEK FAMILY KITCHEN
# Inserted WOK TO WALK
# Inserted BOMBAY MASALA
# Inserted PUEBLA  RESTAURANT
# Inserted MYMOON
# Inserted AJISAI
# Inserted A&S Crown Fried Chicken
# Inserted ALITON'S PIZZA & DELI
# Inserted PIER 79/NY WATERWAY SEATTLE CAFE
# Inserted OAXAQUITA BELLA RESTAURANT AND BAKERY
# Inserted JARDIN DE CHINA REST
# Inserted JUST SALAD
# Inserted CHINA KING FOOD
# Inserted PANERA BREAD
# Inserted NEW GOLDEN STAR
# Inserted SUSHI MESHUGA
# Inserted AREPAS PUES MIXTAS
# Inserted NEW STAR CAFE
# Inserted METATE MEXICAN RESTAURANT
# Inserted CAFE BELLA VITA
# Inserted AIR INDIA LOUNGE
# Inserted TO BE THAI
# Inserted TU SONRISA
# Inserted SUBWAY
# Inserted QUE SABOR BAKERY CAFE
# Inserted CITY ISLAND CHINESE RESTAURANT
# Inserted YUMMY CHINESE RESTAURANT
# Inserted PANEORAMA BAKERY
# Inserted BIEN CUIT
# Inserted POLITO'S PIZZA
# Inserted BAGEL FACTORY
# Inserted CROWN DINER
# Inserted LILI'S 57
# Inserted MASAL CAFE & LOUNGE
# Inserted EAST BUFFET & RESTAURANT
# Inserted EL BLOQUE DELI
# Inserted BEST PIZZA ON 1ST.
# Inserted CHELSEA PAPAYA
# Inserted DUNKIN' DONUTS
# Inserted ORIENTAL CHINESE KITCHEN
# Inserted NEW MAGIC CHEF
# Inserted LASANI RESTAURANT
# Inserted UNO CAFE & BILLIARDS
# Inserted STARBUCKS
# Inserted NAPOLEON'S SOUTHERN CUISINE & BAKERY
# Inserted MCDONALD'S
# Inserted MEXICAN RADIO
# Inserted ALEX CAFE & DELI
# Inserted WHITE CASTLE
# Inserted PUPUSERIA EL COMAL
# Inserted NANNI RESTAURANT
# Inserted BIZARRE
# Inserted 765 FOOD MARKET
# Inserted QUALITY CAFE & RESTAURANT
# Inserted AUNT BUTCHIES CAFE
# Inserted SPEEDY DELI
# Inserted EL CERRITO DEL CARMEN RESTAURANT
# Inserted ARETSKY'S PATROON
# Inserted GOOD GOOD TASTE
# Inserted JOE'S OF AVE U
# Inserted MCDONALD'S
# Inserted COLD STONE CREAMERY
# Inserted RAKU II ITS JAPANESE
# Inserted FRIENDLY'S
# Inserted HILTON NEW YORK MAIN KITCHEN
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted CAFE METRO
# Inserted HENRY
# Inserted BURGER KING
# Inserted MON CHER MARKET
# Inserted SOHO BISTRO
# Inserted BUKHARA GRILL
# Inserted MATSU SUSHI
# Inserted OCEAN CHINESE RESTAURANT
# Inserted BROOKLYN WINE YARD

# %%
from datetime import datetime

# Go over the inspection data and store the time-varying
# data into the appropriate table in the database

def storeTimeVaryingData(con, open_data):
    '''
    Accepts as a parameter a list of dictionaries, where
    each dictionary is an inspection.
    Goes over these dictionaries, and stores in the database
    the entries that are time variant.
    The data is stored if the restaurant ID, inspection date, and violation code, represent a unique 3-pair.
    
    Because not every instance has a violation code or grade, we use a try/except statement
    '''
    
    db_name = 'OpenData'
    table_name = 'inspection_info'
    count = 0
    for store in open_data:
        store_id = store["camis"]
        try:
            store_name = store["dba"]
        except KeyError:
            pass
        try:
            inspection_date  = store["inspection_date"]
        except KeyError:
            pass
        record_date  = store["record_date"]
        try:
            violation_code = store["violation_code"]
        except KeyError:
            pass
        try:
            grade = store["grade"]
        except KeyError:
            grade = None
            pass
        try:
            inspection_type = store["inspection_type"]
        except KeyError:
            pass
        insertStatus(con, db_name, table_name, store_id, store_name, inspection_date, record_date, inspection_type, violation_code, grade)
        count += 1
        print "Inserted", store_name
        
    con.commit()
    
    return
        
def insertStatus(con, db_name, table_name, 
                  store_id, store_name, inspection_date, record_date, inspection_type, violation_code, grade):
    query_template = '''INSERT IGNORE INTO {0}.{1}(store_id,
                                    store_name,
                                    inspection_dt,
                                    record_dt,
                                    inspection_type,
                                    violation_code,
                                    grade)
                VALUES (%s, %s, %s, %s, %s, %s, %s)'''.format(db_name, table_name)

    cursor = con.cursor()
    query_parameters = (store_id, store_name, inspection_date, record_date, inspection_type, violation_code, grade)
    cursor.execute(query_template, query_parameters)
    cursor.close()

    return


storeTimeVaryingData(con, store_data)
# Out:
# Inserted MCDONALD'S
# Inserted EASTERN BLOC
# Inserted WESTSIDE BREWHOUSE
# Inserted CAS' WEST INDIAN & AMERICAN RESTAURANT
# Inserted THE RUM HOUSE
# Inserted HAPPY STAR BAKERY
# Inserted LA MEDITERRANEE RESTAURANT
# Inserted YONG SHENG RESTAURANT
# Inserted VERLAINE
# Inserted EDDIE'S DELI & PIZZA
# Inserted THE KENT ALE HOUSE
# Inserted GREENSTREETS SALADS
# Inserted KIKOO SUSHI
# Inserted HECHO EN DUMBO
# Inserted RIVERDALE STEAK HOUSE
# Inserted WO HOP CITY
# Inserted DAE DONG MANOR
# Inserted SMORGAS CHEF/ CREPES DU NORD
# Inserted LIONS BEER STORE
# Inserted CAFE SHIRIN
# Inserted FORT HAMILTON DINER
# Inserted GLATT ALA CARTE
# Inserted CAESAR'S PALACE
# Inserted EL TAPATIO MEXICAN RESTAURANT
# Inserted TROPICAL 128
# Inserted LUNA
# Inserted SHINOBI RAMEN
# Inserted AKI SUSHI
# Inserted EL RICO TINTO BAKERY
# Inserted TASTY FAST FOOD
# Inserted ROSE BENGAL
# Inserted BONAO BAR AND GRILL
# Inserted SYCAMORE
# Inserted SHARMEL CATERERS
# Inserted JUNIPER
# Inserted MIGHTY QUINN'S BBQ
# Inserted SUGAZ BAR
# Inserted OLI 99¢ FRESH PIZZA
# Inserted MAMA'S FRIED CHICKEN
# Inserted MI TACO SANTANA
# Inserted EL TAPATIO MEXICAN RESTAURANT
# Inserted THE FIFTH ESTATE
# Inserted BEDFORD PIZZA CAFE
# Inserted MEXI JOE'S GRILL
# Inserted TACO BELL
# Inserted MASTER EXPRESS DELI & RESTAURANT
# Inserted LA MONEDA RESTAURANT
# Inserted TROOST
# Inserted KARMA RESTAURANT
# Inserted PARAISO ZONA VIP RESTAURANT BAR
# Inserted LUZ DE AMERICA RESTAURANT
# Inserted ROCK BAR
# Inserted WYTHE DINER/ LA ESQUINA
# Inserted JOSEPH LEONARD
# Inserted EL ANZUELO FINO RESTAURANT
# Inserted NEW KIM'S RESTAURANT
# Inserted MCDONALD'S
# Inserted REX CHELSEA
# Inserted THE CANNIBAL
# Inserted DIECI
# Inserted THE CITY BAKERY
# Inserted TUNG THONG THAI RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted ILILI RESTAURANT
# Inserted MADIBA
# Inserted HOT SICHUAN
# Inserted ISLAND SOFT PRETZEL STOP
# Inserted OH TAISHO
# Inserted THE STANDARD
# Inserted VACCARO'S PIZZERIA & TRATTORIA
# Inserted WINDFALL
# Inserted THOMASINA'S CATERING HALL
# Inserted PIO HOT BAGELS
# Inserted WTF COFFEE & TEA
# Inserted MANGOS PARADISE SMOOTHIE
# Inserted NEW TIMES CHINESE RESTAURANT
# Inserted MR. WONTON
# Inserted CHUCK E. CHEESE'S
# Inserted CORONA PIZZA
# Inserted CROWN DINER
# Inserted 9 & 8 CAFE
# Inserted MCDONALD'S
# Inserted TUCK SHOP
# Inserted STROMBOLI PIZZA
# Inserted ZUCKER'S BAGEL
# Inserted 9TH AVE SALOON
# Inserted LOS CUENCANITOS
# Inserted HUNTER'S
# Inserted SATI'S ROTI SHOP
# Inserted CARVEL ICE CREAM
# Inserted EL NUEVO ATLANTIC LOUNGE
# Inserted TORO
# Inserted XES LOUNGE
# Inserted CHINA KITCHEN
# Inserted 121 FULTON STREET
# Inserted 211 NEW TACO GRILL
# Inserted TACO KING
# Inserted YI ZHANG FISHBALL
# Inserted KARLOFF
# Inserted THE ABBEY
# Inserted STANTON SOCIAL
# Inserted RED VELVET HOOKAH LOUNGE
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted MIKE'S PUB
# Inserted LIN'S NO 1 CHINESE RESTAURANT
# Inserted KYOTO SUSHI V
# Inserted THE 5 AND DIAMOND
# Inserted OSAKA JAPANESE FUSION
# Inserted LUIGI PIZZERIA & RISTORANTE
# Inserted KUNG FU XIAO LONG BAO
# Inserted ROASTOWN
# Inserted DIAMOND KRUST
# Inserted PARRILLA LATINA
# Inserted BARNES & NOBLE CAFE
# Inserted IL TOSCANO RISTORANTE
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted RED STIXS
# Inserted RAVAGH PERSIAN GRILL
# Inserted CAFE 75 BAR
# Inserted KITARO
# Inserted TOMMY PIZZERIA
# Inserted LULU & PO
# Inserted CHO-SEN GARDEN
# Inserted SUNSET DINER
# Inserted GP SMOOTHIES & GIFTSHOP
# Inserted PIZZA PLUS
# Inserted CAFE RESTAURANT
# Inserted EL NUEVO YAUCO RESTAURANT
# Inserted LITTLE BROWN JUG
# Inserted Manon Cafe / Leonidas
# Inserted ZEFES MEXICAN RESTAURANT
# Inserted TABARE
# Inserted A & S CATERERS
# Inserted HIMALAYAN YAK RESTAURANT
# Inserted WOOPS! BAKESHOP
# Inserted EL HORNERO BAKERY
# Inserted (LEWIS DRUG STORE) LOCANDA VINI E OLII
# Inserted THAI TONY'S
# Inserted RECETTE
# Inserted EL GRAN VALLE II
# Inserted HILTON HOTEL JFK AIRPORT
# Inserted BELLA VITA
# Inserted PIZZA BEACH
# Inserted KLIMAT
# Inserted 101 RESTAURANT AND BAR
# Inserted DELTA SKY CLUB (BARTENDER SERVICE TERMINAL D DELTA DEPARTURE)
# Inserted SCALETTA RISTORANTE
# Inserted PUBLIC RESTAURANT/THE DAILY
# Inserted EAST SEAFOOD RESTAURANT
# Inserted EL GIRASOL BAKERY
# Inserted SARAGHINA
# Inserted PICK-A-BAGEL
# Inserted Bar B
# Inserted L AND Z BAKERY
# Inserted PINCHE TAQUIERA
# Inserted MEDINA FRIED CHICKEN & INDIAN CUISINE
# Inserted MCDONALD'S
# Inserted CAFE DUKE
# Inserted MATCH 65
# Inserted CHEF YU / AZUKI
# Inserted CRUMBS BAKE SHOP
# Inserted TONIC EAST
# Inserted ROADHOUSE RESTAURANT
# Inserted BHATTI INDIAN GRILL
# Inserted IRIS TEA & BAKERY, QUICKLY
# Inserted HAPPY SU GARDEN
# Inserted MC ANN'S
# Inserted STARBUCKS
# Inserted THE PINK TEA CUP
# Inserted SUBWAY
# Inserted DC KTV
# Inserted CROXLEYS THE ABBEY
# Inserted FISHERMAN'S COVE
# Inserted SIMIT AND SMITH
# Inserted PANCHITO'S
# Inserted DOMINO'S
# Inserted BLACK SEED BAGELS
# Inserted 652 LIN'S GARDEN
# Inserted POLLOS MARIO
# Inserted PICK & PAY GYRO & PIZZA
# Inserted EL MAGUEY Y LA TUNA
# Inserted Patea
# Inserted SNACKS-N-WHEELS
# Inserted NEW YORKER HOTEL KITCHEN
# Inserted DON COGUI
# Inserted NORTHERN SUSHI
# Inserted LA RIVISTA RESTAURANT
# Inserted LA VIE
# Inserted FPB  BAKERY
# Inserted MASHA LI/TIAN SHANG REN JIAN BAR
# Inserted HUNTER'S
# Inserted TRADICIONES LATINAS RESTAURANT
# Inserted CROWN GOURMET DELI
# Inserted PIZZA HUT
# Inserted AL'S DELI
# Inserted TACO BELL
# Inserted CHIFLEZ
# Inserted UNCLE'S FRIED CHICKEN
# Inserted SHIH LEE CHINESE GOODEATS
# Inserted FRITZIES BAKE SHOP
# Inserted KAT'S ISLAND CUISINE
# Inserted STATEN ISLAND DINER
# Inserted DILEO'S PIZZERIA
# Inserted PLAZA FOOD COURT
# Inserted WENDY'S
# Inserted SUBWAY
# Inserted MOM'S BAKERY
# Inserted JUQUILITA BAR
# Inserted GRAND SICHUAN
# Inserted BAGEL LAND
# Inserted COCORON
# Inserted JOHN'S DELI
# Inserted MEENA HOUSE CAFE
# Inserted FASTWAY RESTAURANT
# Inserted TASTY BITES
# Inserted HILLSIDE HOT BAGELS
# Inserted PADDY'S REILLY'S BAR
# Inserted WING HING SEAFOOD RESTAURANT
# Inserted CASCABEL TAQUERIA
# Inserted CAFE OMAR/PATTY PALACE
# Inserted LA PENTOLA ITALIAN PIZZERIA
# Inserted TERRA
# Inserted BRANCH OFC
# Inserted DOMAINE WINE BAR
# Inserted RADIANCE
# Inserted HARLEM TAVERN
# Inserted RICHIE RICH CARIBBEAN TASTE II
# Inserted AH ZHONG FOOD STORE # 5
# Inserted CARVEL ICE CREAM
# Inserted FIVE GUYS FAMOUS BURGERS AND FRIES
# Inserted GOURMET 45
# Inserted WILLIAMSBURG PIZZA
# Inserted NEW GARDEN
# Inserted IHOP
# Inserted DUNKIN' DONUTS
# Inserted CANOA
# Inserted WILLIAM HALLET
# Inserted PAPAYA DOG 42ND ST
# Inserted LIBERTY CATERING
# Inserted DEUX AMIS
# Inserted LOS TRES POTRILLOS RESTAURANT
# Inserted TRATTORIA L'INCONTRO
# Inserted YONAH SHIMMELS KNISHES
# Inserted RALPH'S ICES
# Inserted NEW ARPING RESTAURANT
# Inserted DEL CORSO PIZZERIA
# Inserted CROWN FRIED CHICKEN
# Inserted EL REY DE LA CARIDAD
# Inserted Lan Zhou Handmade Noodle
# Inserted MAJA'S TAPAS RESTAURANT BAR
# Inserted CHU'S GOURMET
# Inserted OH TAISHO
# Inserted SUN SAI GAI RESTAURANT
# Inserted VISTA HERMOSA DELI RESTAURANT
# Inserted HAPPY SU GARDEN
# Inserted PAPA JOHN'S
# Inserted CAFE RUBIO
# Inserted NEW SOUL CAFE
# Inserted FAY DA BAKERY
# Inserted CECI RESTAURANT
# Inserted BLUE GINGER
# Inserted EL MANGU SABROSO RESTAURANT
# Inserted ARCHWAY CAFE (unit 114) on PEARL ST
# Inserted THE LONG ROOM
# Inserted LA ISLA CAFE RESTAURANT
# Inserted PINE RESTAURANT
# Inserted KING HOUSE RESTAURANT
# Inserted SEVEN TURKISH GRILL
# Inserted CEBU
# Inserted JOYA
# Inserted LITTLE ITALY PIZZA
# Inserted L' CHAIM CAFE
# Inserted DOMINO'S
# Inserted EL NUEVO SABOR LATINO
# Inserted NANCY'S RESTAURANT
# Inserted HUNAN DELIGHT
# Inserted NO 7 NORTH
# Inserted BELLA NAPOLI
# Inserted ZAMAAN HOOKAH BAR
# Inserted SAN PIETRO
# Inserted OAXACA TAQUERIA
# Inserted DUNKIN' DONUTS
# Inserted BENTON CAFE
# Inserted JUQUILITA BAR
# Inserted BOSSA NOVA CIVIC CLUB
# Inserted C & L BAKERY
# Inserted RAKU II ITS JAPANESE
# Inserted TACOMBI AT FONDA NOLITA
# Inserted K ONE BUFFET
# Inserted NOSH! - COURTYARD BY MARRIOTT
# Inserted GORDON BENNETT
# Inserted MILL BASIN BAGEL CAFE
# Inserted SAW SHACK
# Inserted OMONIA NEXT DOOR
# Inserted THE KING OF EMPANADAS
# Inserted KABIRS BAKERY
# Inserted HIDE CHAN RAMEN
# Inserted EAT & GO ISTANBUL/NEW YORK
# Inserted LUCKY PIZZA
# Inserted YET-NAL JJAJANG
# Inserted CARVEL ICE CREAM
# Inserted IT'Z ALL 4 U
# Inserted WEST 53RD GOURMET DELI
# Inserted 5 STAR CHEESE STEAK AND PIZZA
# Inserted PLANET WINGS
# Inserted EL VALLE RESTAURANT
# Inserted LE BASKET
# Inserted CHEN'S GARDEN
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted PAPA JOHN'S
# Inserted MERCY COLLEGE
# Inserted TACO Y MAS
# Inserted WAZA SUSHI
# Inserted BANGAL CURRY
# Inserted ALEX LUNCHEONETTE
# Inserted SZECHUAN PALACE
# Inserted FASHION INSTITUTE OF TECHNOLOGY DAVID DUBINSKY STUDENT CENTER
# Inserted HAPPY STAR BAKERY
# Inserted PETER LUGER STEAKHOUSE
# Inserted SUBWAY
# Inserted COURT STREET BAGELS
# Inserted PONCHE TAQUERIA
# Inserted RED SPOON
# Inserted EL NUEVO SABOR LATINO
# Inserted NEW CHINA STAR
# Inserted THIS & THAT
# Inserted OMEN JAPANESE CUISINE
# Inserted ROLL-N-ROASTER
# Inserted EVERGREEN RESTAURANT
# Inserted J & JOE DELI & GROCERY
# Inserted LA PARADA RESTAURANT
# Inserted COLLEGE POINT MULTIPLEX CINEMAS
# Inserted EL RUMBERO BAR RESTAURANT
# Inserted BROTHER JIMMY'S BBQ
# Inserted JOEY PEPPERONI'S PIZZA
# Inserted TABARE
# Inserted EL CONQUISTADOR RESTAURANT
# Inserted ODRADEKS COFFEE HOUSE
# Inserted FONDA
# Inserted PIER 79/NY WATERWAY SEATTLE CAFE
# Inserted KREYOL FLAVOR
# Inserted GOODY'S SPANISH FOOD
# Inserted TIELLA RESTAURANT
# Inserted THE BUTHCHER'S DAUGHTER MARKET
# Inserted LEA
# Inserted MURPHY'S TAVERN
# Inserted BAGELS N GREENS
# Inserted BLARNEY CASTLE
# Inserted PREVITI PIZZA
# Inserted MAX
# Inserted SAM'S
# Inserted HILLSIDE GOURMET
# Inserted TEXAS STAR SNACK BAR
# Inserted WHISKEY TOWN
# Inserted NEW RED FLOWER CHINESE RESTAURANT
# Inserted MICHAEL & SONS ITALIAN FOOD & PIZZA
# Inserted SOFIA PIZZA RESTAURANT
# Inserted WENG'S PALACE
# Inserted DUNKIN' DONUTS
# Inserted POMODORI
# Inserted CUE BAR
# Inserted EASTERN OCEAN CHINA KING RESTAURANT
# Inserted NEW CORNER
# Inserted LEE'S TAVERN
# Inserted THE MANHATTAN AT TIMES SQUARE
# Inserted ANYWAY CAFE BAR
# Inserted THE COMMONS CHELSEA
# Inserted MCDONALD'S
# Inserted THE VILLAGE LANTERN
# Inserted BILLIARD COMPANY
# Inserted METRO CAFE
# Inserted SHERWOODS KEEP
# Inserted SOL DE QUITO RESTAURANT
# Inserted THE CREEK AND THE CAVE
# Inserted AUNT BUTCHIES CAFE
# Inserted DOUBLE DRAGON RESTAURANT
# Inserted PETE'S CAFE
# Inserted EL GRAN CANARIO RESTAURANT
# Inserted CHINA KING
# Inserted HEAVENLY MIRACLE ACADEMY DAY CARE CENTER
# Inserted DOWNTOWN BAKERY II MEXICAN FOOD
# Inserted FOOD LIN
# Inserted GLEESON'S SPORTS BAR
# Inserted THE DART INN
# Inserted GINGER'S BAR
# Inserted BLAKE AND TODD
# Inserted CARIDAD CHINA RESTAURANT
# Inserted IL FORNO OF BROOKLYN
# Inserted DANTE'S GOURMET FOOD
# Inserted BOWLMOR CHELSEA PIERS
# Inserted LECHONERA TROPICAL & GRILL
# Inserted CHIMU
# Inserted EL CASTILLO DEL POLLO COFFEE SHOP
# Inserted ORIGINAL SANDWICHES
# Inserted PICANTERIA EL AUSTRO
# Inserted OCEAN GRILL
# Inserted CITI BAGEL & DELI
# Inserted TUTTI MATTI
# Inserted LA ABUNDANCIA BAKERY
# Inserted TANDOOR PALACE
# Inserted YUMMY SZECHUAN HOUSE
# Inserted ALMAR
# Inserted WEST CARIBBEAN INTERNATIONAL RESTAURANT
# Inserted SUBWAY
# Inserted LA BELLA PIZZA
# Inserted 739 FRANKLIN BAR & LOUNGE
# Inserted LA SABROSURA
# Inserted GREAT WALL RESTAURANT
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted CATALDO'S RESTAURANT
# Inserted RAMEN THUKPA
# Inserted PARIS BLUES
# Inserted TOTTO RAMEN
# Inserted SWINE
# Inserted GABRIELLA CAFE
# Inserted CHINA TASTE
# Inserted SMILE TO GO
# Inserted KAT'S TASTY GRILL
# Inserted PAPA JOHN'S
# Inserted 55 BAR
# Inserted NY DC CAFE
# Inserted NANCY WHISKEY PUB
# Inserted AH! CHIHUAHUA
# Inserted DUNKIN' DONUTS
# Inserted LA NORTENA
# Inserted LA CASA BELLA
# Inserted OLLA WINE BAR
# Inserted FUJI BAKERY
# Inserted FULTON CAFE
# Inserted SHOPSINS GENERAL STORE (STORE #16)
# Inserted RJC FAMILY'S CAFE
# Inserted BOOM BOOM ROOM, LE BAIN, THE STANDARD
# Inserted NANA RESTAURANT & BAR
# Inserted Central Station
# Inserted TINA'S RESTAURANT
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted T.G.I. FRIDAY'S
# Inserted TRATTORIA PESCE PASTA
# Inserted MUCHMORE'S
# Inserted LENNY'S PIZZA
# Inserted KAFFE 1668
# Inserted MERIT KABAB PALACE
# Inserted TAZZA
# Inserted NEW ASIAN RESTAURANT
# Inserted MMM THATS A WRAP
# Inserted RUBI ROSA RESTAURANT & BAR
# Inserted 12 CORNERS
# Inserted EL GRAN MALECON RESTAURANT
# Inserted BELLA NAPOLI
# Inserted PIORA
# Inserted VANESSA'S DUMPLING HOUSE
# Inserted 456 RESTAURANT
# Inserted SALTY DOG RESTAURANT
# Inserted IGNAZIO'S
# Inserted CIPRIANI 42ND STREET
# Inserted JAMBA JUICE
# Inserted PRONTO RESTAURANT
# Inserted STAND 139 TACO FRITES
# Inserted GINGER
# Inserted ISLAND BLEND JUICE  BAR .
# Inserted ERAWAN THAI CUISINE
# Inserted JOHN'S FRIED CHICKEN
# Inserted O'S GRILL SPOT
# Inserted BLACK IRIS MIDDLE EASTERN CUISINE
# Inserted MOZZARELLA & VINO
# Inserted CASTILLO ECUATORIANO RESTAURANT
# Inserted CHEETAHS GENTLEMENS CLUB & RESTAURANT
# Inserted ST. ALBANS PIZZERIA
# Inserted PARADISO NY
# Inserted STARBUCKS
# Inserted AVE NIDA
# Inserted SIGIRI
# Inserted MAXIM CHINESE RESTAURANT
# Inserted EL NUEVO JB BAKERY
# Inserted SUBWAY
# Inserted CHOPSTIX
# Inserted PITKIN BONAO GRILL RESTAURANT
# Inserted S & S HOT SPOT ROTI SHOP & RESTAURANT
# Inserted AUDREY'S CONCERTO
# Inserted ZUTTO
# Inserted MANNY'S ON SECOND
# Inserted SWEET & VICIOUS
# Inserted ROMANIAN GARDEN
# Inserted SOLDIERS CARIBBEAN RESTAURANT
# Inserted PLENTY CAFE BAKERY CATERING
# Inserted PACIFICANA REST
# Inserted THE SQUEEZE
# Inserted LA GUADALUPANA RESTAURANT
# Inserted THE RAGING SKILLET
# Inserted WOK WOK RESTAURANT
# Inserted MADDY'S
# Inserted IMPERIAL PALACE
# Inserted GREENWICH VILLAGE BISTRO
# Inserted HILTON GARDEN INN
# Inserted ARTHUR'S TAVERN
# Inserted BERGER'S ON THE GO
# Inserted CAFE BORA BORA
# Inserted BAREBURGER
# Inserted RAINES LAW ROOM
# Inserted DOMINO'S
# Inserted EASTERN OCEAN ONE
# Inserted LUCKY ZHANG'S FAMILY
# Inserted JIAN ON CHINESE RESTAURANT
# Inserted LE PAIN QUOTIDIEN
# Inserted COLUMBUS FLAME
# Inserted SALUD SOHO
# Inserted YAMATO JAPANESE CUISINE
# Inserted SOUTH'S
# Inserted LA CUARTA RESTAURANT
# Inserted PADO SUSHI
# Inserted MONTE LIMAR SPORT BAR LOUNGE
# Inserted GIORGIONE
# Inserted KRISPY PIZZERIA
# Inserted GOURMET GRILL
# Inserted DA NICO RESTAURANT
# Inserted HOP KEE RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted CHEN'S GARDEN
# Inserted JAMAO COFFEE SHOP RESTAURANT
# Inserted WHITMAN & BLOOM
# Inserted Pick-A-Bagel
# Inserted TOTTENVILLE BAGELS
# Inserted AMY'S BREAD
# Inserted DRINK
# Inserted BIJAN'S
# Inserted METROPOLITAN CLUB
# Inserted MIA
# Inserted RESTAURANTE & PANADERIA GUATELINDA
# Inserted THE BEEKMAN
# Inserted THE RAIL LINE DINER
# Inserted PAZZA NOTTE
# Inserted SCHNIPPERS
# Inserted DEUTSCHE BANK CONFERENCE CENTER
# Inserted CAFE HABANA/CAFE HABANA TO GO
# Inserted EDDIE FANCY FOOD
# Inserted NEEROB
# Inserted LAS AMERICAS BAKERY
# Inserted MS. DAHLIA'S CAFE
# Inserted THE MAD DONKEY
# Inserted DUNKIN' DONUTS
# Inserted THE HEIGHTS BAR & GRILL
# Inserted CARRERA BAKERY
# Inserted MAITE
# Inserted MCDONALD AVENUE DINER
# Inserted PORTO BELLO PIZZERIA & RESTAURANT
# Inserted BACK HOME BAKERY
# Inserted OLIVE TREE
# Inserted FREDDY'S PIZZA
# Inserted TAVERN ON THE THIRD
# Inserted CAVALA
# Inserted THE STANDING ROOM
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted LORELEY RESTAURANT
# Inserted CHINESE FOOD RESTAURANT
# Inserted EASY CORNER RESTAURANT & GRILL
# Inserted FRAME GOURMET EATERY
# Inserted KFC
# Inserted GALLI RESTAURANT
# Inserted DOUBLE HAPPY RESTAURANT
# Inserted THE CAKE CHEF
# Inserted C J's BAR & LOUNGE
# Inserted RED STAR sandwich shop
# Inserted MING WONG RESTAURANT
# Inserted WB CARIBBEAN RESTAURANT
# Inserted BOAT HOUSE & CAJUN CUISINE
# Inserted FRANKS PIZZA
# Inserted vapor lounge
# Inserted RED APPLE
# Inserted FELIDIA RESTAURANT
# Inserted VINA DEL MAR RESTAURANT
# Inserted CITY LINE PIZZA & PASTA
# Inserted FRANK'S PIZZA RESTAURANT
# Inserted NEW ANDY'S DELI
# Inserted JIMBO'S HAMBURGER PALACE
# Inserted NERAI
# Inserted D'BLASS RESTAURANT
# Inserted RED MANGO
# Inserted LAS AMERICAS BAKERY
# Inserted GOOD WOK CHINESE RESTAURANT
# Inserted STARBUCKS
# Inserted THE SAINT CATHERINE
# Inserted RED MANGO
# Inserted PEACHWAVE FROZEN YOGURT
# Inserted JUICE GENERATION
# Inserted GREAT N.Y. NOODLETOWN
# Inserted PIZZA BELLA
# Inserted CROSS BRONX PIZZERIA
# Inserted FU HAI RESTAURANT
# Inserted GINO'S PIZZERIA
# Inserted BUTTERFIELD CATERING
# Inserted BIRDBATH
# Inserted RAMEN-YA
# Inserted KENNEDY FRIED CHICKEN
# Inserted HALLAL SANDWICH SHOP
# Inserted LITTLE ITALY PIZZA/PAPAYA DOG
# Inserted HO YIP RESTAURANT
# Inserted ALL'ONDA
# Inserted JUNGLE CAFE
# Inserted CAFFE E VINO
# Inserted BEN'S PIZZA
# Inserted BLACK TREE
# Inserted NEW JADE HOUSE
# Inserted GOLDEN PLACE
# Inserted CAFE METRO
# Inserted DRAM SHOP
# Inserted VICTOR'S CAFE
# Inserted VILLAGE MARIA PIZZA II
# Inserted TWO BOOTS
# Inserted CULTURE 36
# Inserted HAAGEN-DAZS
# Inserted LA MIA PIZZA
# Inserted Bagel Bistro & Diner
# Inserted CASA MEZCAL
# Inserted PARIS BAGUETTE
# Inserted THE CORNELL CENTER OF NEW YORK
# Inserted CLOUD 9
# Inserted CHINA RED GOURMENT
# Inserted OLLIES 42ND
# Inserted CAFE RUBIO
# Inserted LA DOLCE ITALIA BAKERY
# Inserted MOJITO CUBAN CUISINE
# Inserted FISHERMAN'S COVE
# Inserted HAAGEN-DAZS
# Inserted EL FAMILAR RESTAURANT
# Inserted JIN RAMEN
# Inserted THE LUTHERAN HALAL CAFE
# Inserted STARBUCKS
# Inserted HOP LEE RESTARANT
# Inserted SING SING KARAOKE
# Inserted J & C DELICIAS
# Inserted ISAACS COFFEE SHOP
# Inserted JAMEX SPORTS BAR
# Inserted STONE STREET COFFEE COMPANY
# Inserted BHUTANESE EMA DATSI RESTAURANT
# Inserted EL CHICANITO RESTAURANT BAR
# Inserted LA GITANA PANADERIA - RESTAURANTE
# Inserted TACOS MEXICO
# Inserted NEW DRAGON TOWN OF MANHATTAN
# Inserted HALE & HEARTY SOUP
# Inserted 86 BAKERY
# Inserted HUSH CAFE LOUNGE & GARDEN
# Inserted THOMASINA'S CATERING HALL
# Inserted LA GATA GOLOSA
# Inserted DO HWA
# Inserted HAVANA CAFE (SECTION 10)
# Inserted B.B. KINGS
# Inserted ZEFF'S PIZZERIA
# Inserted LEE'S KITCHEN
# Inserted HOP LEE KITCHEN
# Inserted LARK
# Inserted FOOTPRINTS CAFE EXPRESS
# Inserted A TASTE OF SHANGHAI RESTAURANT
# Inserted CITI EMPLOYEE CAFETERIA
# Inserted MOE'S SOUTHWEST GRILL
# Inserted SOLACE BAR & GRILL
# Inserted QUEEN BAKERY II
# Inserted AMANECER LATINO RESTAURANT
# Inserted NONNA'S OLD FASHIONED PIZZERIA / NONNA'S BAGELS
# Inserted CRIME SCENE
# Inserted HADJA MARLEY RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted CITY COLLEGE CAFETERIA
# Inserted TROYKA/DA MIKELLE PALACE/MIKELLE CORNER/SUSHI & STEAK HOUSE
# Inserted KAT'S ISLAND CUISINE
# Inserted MUI KITCHEN & BAR
# Inserted ZAGARA WINE BAR
# Inserted TSION CAFE & BAKERY
# Inserted BREADZONE
# Inserted MI PALENQUE
# Inserted PLANET WINGS
# Inserted ABC KITCHEN
# Inserted THIS & THAT
# Inserted COURT STREET GROCERS
# Inserted BEN & JERRY'S
# Inserted BASURERO
# Inserted FRESCO BAR CAFE RESTAURANT
# Inserted MOE'S CAFE
# Inserted MONTEZUMA RESTAURANT
# Inserted BONCHON
# Inserted FIORENTINO RISTORANTE
# Inserted DOMINO'S
# Inserted Campagnola Restaurant
# Inserted LA DINASTIA
# Inserted TONY'S FAMOUS PIZZA
# Inserted CHOCOLAT
# Inserted DREDSURFER GRILL
# Inserted J & R PIZZERIA NO. 2
# Inserted BLEACHERS 67 SPORTS BAR AND GRILL
# Inserted BROTHERS FISH MARKET
# Inserted BAY HOUSE BISTRO
# Inserted NICKS PLACE
# Inserted BLUE RIBBON SUSHI BAR & GRILL
# Inserted MUSIC HALL OF WILLIAMSBURG
# Inserted NEW PUNJAB RESTAURANT & GRILL
# Inserted CORNERSTONE CAFE
# Inserted I & R DELI
# Inserted FRONT STREET PIZZA
# Inserted KENNEDY FRIED CHICKEN
# Inserted HUNAN GLATT KOSHER
# Inserted SIAM ORCHID THAI RESTAURANT
# Inserted MAHAICA HOT SPOT & RESTAURANT
# Inserted WASHINGTON BAGEL CAFE
# Inserted BREAD
# Inserted MACDOUGAL STREET ALE HOUSE
# Inserted MCDONALD'S
# Inserted OXFORD CAFE
# Inserted HANGAR 11 BAR & GRILL
# Inserted ROYAL PIZZA
# Inserted AROMA
# Inserted BROOME STREET BAR
# Inserted GREEN SKY RESTAURANT
# Inserted DUNKIN' DONUTS
# Inserted 21 SHANGHAI HOUSE
# Inserted TACO BELL
# Inserted NINOS 46
# Inserted UNO PIZZERIA AND GRILL
# Inserted CHINA PEKING RESTAURANT
# Inserted LOS BALBUENA RESTAURANT
# Inserted SUBWAY
# Inserted INDIGO INDIAN CUISINE
# Inserted JERUSALEM II PIZZA
# Inserted MIKE'S DINER
# Inserted HIGHLINE BALLROOM
# Inserted JR. BELLA'S PIZZA & PASTA 2
# Inserted MURPHY'S LAW
# Inserted MEXICAN RESTAURANT
# Inserted THE PUMP JUICE BAR
# Inserted PONGSRI THAI RESTAURANT
# Inserted HAMPTON INN & SUITES
# Inserted PAPPARDELLA
# Inserted cervecceria Havemeyer
# Inserted HIDE CHAN RAMEN
# Inserted LIC MARKET
# Inserted T.G.I. FRIDAY'S
# Inserted DUNKIN' DONUTS
# Inserted CHARO RESTAURANT
# Inserted LE PADDOCK
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted THE AUSTRALIAN
# Inserted MAMA MIA 44 SW
# Inserted EL REY
# Inserted MADDEN'S PUB
# Inserted 18 STARS KITCHEN
# Inserted LATINO EXPRESS RESTAURANT
# Inserted STAND 213
# Inserted CALIFORNIA PIZZA KITCHEN
# Inserted CARLOS AND GABBY'S CANTINA GRILL
# Inserted HOT JALAPENO RESTAURANT
# Inserted B & M HOT BAGEL & GROCERY
# Inserted KAFF KAFE
# Inserted LAS PANTERAS NEGRAS RESTAURANT
# Inserted TREND DINER
# Inserted LIBERTY DINER
# Inserted NEW TASTE OF CHINA
# Inserted CROWN FRIED CHICKEN
# Inserted BOHEMIAN NEW YORK
# Inserted BLOSSOM DU JOUR
# Inserted STEEL PAN
# Inserted 100 montaditos
# Inserted EL REY DE LA CARIDAD
# Inserted BLOSSOM DU JOUR
# Inserted VIA QUADRONNO
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted DUNKIN' DONUTS, BASKIN ROBBINS
# Inserted SARILING ATIN
# Inserted RISTORANTE LUNA
# Inserted WILD GINGER VEGAN CAFE
# Inserted BUKHARA GRILL
# Inserted GREEN TOMATO
# Inserted WONDERFUL RESTAURANT
# Inserted BRISAS DEL MAR SEAFOOD MARKET
# Inserted KING DRAGON
# Inserted COSTA BRAVA RESTAURANT
# Inserted L AND Z BAKERY
# Inserted KAFENEO
# Inserted S & J KITCHEN
# Inserted BED-STUY FISH FRY
# Inserted SUGAZ BAR
# Inserted YOURS & MINE RESTAURANT
# Inserted BAGEL CLUB
# Inserted FLATIRON LOUNGE
# Inserted RED FLAME DINER
# Inserted BETTOLONA
# Inserted AKWAABA RESTAURANT
# Inserted RICO CHIMI
# Inserted HOT BAR COLD BAR
# Inserted MARIO'S PIZZERIA
# Inserted Greenforce Juice
# Inserted YU SUSHI
# Inserted NEW KABAB DINER
# Inserted THE THREE MONKEYS
# Inserted NEW GREAT TASTE RESTAURANT
# Inserted GEO SI GI
# Inserted CANCUN MEXICAN RESTAURANT
# Inserted YUMMY DIM SUM
# Inserted MOFONGO DEL VALLE
# Inserted LA GUARIDA BAR
# Inserted LATINO RESTAURANT
# Inserted VILLAGE NATURAL
# Inserted QUALITY FOOD CHINESE KITCHEN
# Inserted 2 BROS PIZZA
# Inserted RITZ BAR
# Inserted GRANDAISY BAKERY
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted CEMITAS PUEBLA RESTAURANT
# Inserted AMURA JAPANESE RESTAURANT
# Inserted GO-GO'S DELI & CONVENIENCE
# Inserted RIBALTA
# Inserted THE COFFEE BEAN & TEA LEAF
# Inserted TEAFFEE
# Inserted TONE AUTHENTIC GEORGIAN BAKERY & CUISINE
# Inserted BAGELICIOUS
# Inserted ANKA GRILL
# Inserted DOMINO'S
# Inserted ANTOJITOS DELI FOOD
# Inserted SARGE'S
# Inserted HONK KONG BOY RESTAURANT
# Inserted NEW CHINA DELIGHT
# Inserted MOMOFUKU MILK BAR UWS
# Inserted TAL BAGELS
# Inserted PATES PLUS BAKERY
# Inserted YOOGLERS FROZEN YOGURT
# Inserted MAISON KAYSER
# Inserted BRISAS DEL MAR RESTAURANT
# Inserted BED-STUY FISH FRY
# Inserted APERITIVO PIZZA BAR
# Inserted TRANQUILITY BAR & LOUNGE
# Inserted BASSANOVA RAMEN
# Inserted LUKE'S PIZZA
# Inserted PRET A MANGER
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted TRUFA RESTAURANT
# Inserted DESMOND'S TAVERN
# Inserted FAMOUS AMADEUS PIZZA
# Inserted Brickhouse Pizzeria
# Inserted CHO-SEN GARDEN
# Inserted MARIO'S PIZZERIA
# Inserted LA CARRETA RESTAURANT
# Inserted DRAGON CITY
# Inserted PAPA JOHN'S
# Inserted JOE'S CRAB SHACK
# Inserted THE PIT AT PEOPLES IMPROV THEATER
# Inserted MOONSTRUCK DINER
# Inserted ISLAND GROVE RESTAURANT
# Inserted HURON CLUB/SOHO PLAYHOUSE
# Inserted SZECHUAN KITCHEN
# Inserted THE ROCK SHOP
# Inserted VIA QUADRONNO
# Inserted NEWTOWN
# Inserted BIG WONG RESTAURANT
# Inserted ST MAZIE
# Inserted CHINANTLA RESTAURANT
# Inserted MI BELLA DAMA RESTAURANT
# Inserted PIAXTLA ES MEXICO DELI
# Inserted XING HUI LINDA KITCHEN
# Inserted TRATTORIA L'INCONTRO
# Inserted HIBISCUS RESTAURANT
# Inserted DRAGON STAR
# Inserted NUEVA ESPERANZA
# Inserted GUAYACO FOOD & ROLLAS
# Inserted DEAN STREET
# Inserted BREAK BAR & BILLARDS
# Inserted WENDY'S
# Inserted CHINA MOON CHINESE RESTAURANT
# Inserted CIAO FOR NOW
# Inserted GARDEN OF EAT-IN
# Inserted YUMMY CHINESE KITCHEN
# Inserted EL JAYA RESTAURANT
# Inserted NEW TRADITIONS
# Inserted MIKE'S ISLAND GRILL RESTAURANT
# Inserted GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Inserted Big E's Deli
# Inserted MI SABOR CAFE
# Inserted PIAXTLA ES MEXICO DELI
# Inserted RICHI RICH PALACE
# Inserted SUBWAY
# Inserted LIN LONG XUAN RESTAURANT INC
# Inserted COLLADO RESTAURANT
# Inserted THUNDER JACKSONS URBAN ROADHOUSE
# Inserted CAFE PRAGUE
# Inserted QUARTINO BOTTEGA ORGANICA
# Inserted THAI ELEPHANT RESTAURANT
# Inserted AL CHOLO BAKERY
# Inserted REPUBLIC RESTAURANT
# Inserted YEE LI RESTAURANT
# Inserted TWIN DONUTS
# Inserted SNACK BAR
# Inserted JP'S WATERSIDE RESTAURANT
# Inserted WINE BAR & RISTORANTE
# Inserted SAHARA ARK
# Inserted PIANOS
# Inserted LUCKY ZHANG'S FAMILY
# Inserted SMASHBURGER
# Inserted tutto il giorno
# Inserted BALCON QUITENO RESTAURANT
# Inserted SIK GAEK
# Inserted JAZZY WEST INDIAN AND AMERICAN RESTAURANT
# Inserted BOBBY VAN'S
# Inserted JIREH RESTAURANT
# Inserted MERCURY BAR
# Inserted NAPOLEON'S SOUTHERN CUISINE & BAKERY
# Inserted TERESA'S GOURMET
# Inserted MIKE'S UNICORN DINER
# Inserted BREWSKI'S BAR & GRILL
# Inserted SUBWAY
# Inserted BREWSKI'S BAR & GRILL
# Inserted THE LIGHTS OF BAKU
# Inserted PASTICCERIA LA TORRE
# Inserted CAFFE BENE
# Inserted STAR CAFE
# Inserted AUREOLE
# Inserted HOTEL CHANTELLE
# Inserted ANGELOS DELI RESTAURANT
# Inserted GIRALDA BAKERY
# Inserted HANG LEE RESTAURANT
# Inserted TRATTORIA 35
# Inserted 3 BROTHERS TURKISH FOOD MARKET
# Inserted DOMINO'S
# Inserted CLADDAGH INN
# Inserted FLUTE
# Inserted THE AVENUE
# Inserted DUNKIN' DONUTS
# Inserted CARLOS & GABBY'S
# Inserted OTARIAN
# Inserted TULCINGO RESTAURANT
# Inserted GREEK FAMILY KITCHEN
# Inserted WOK TO WALK
# Inserted BOMBAY MASALA
# Inserted PUEBLA  RESTAURANT
# Inserted MYMOON
# Inserted AJISAI
# Inserted A&S Crown Fried Chicken
# Inserted ALITON'S PIZZA & DELI
# Inserted PIER 79/NY WATERWAY SEATTLE CAFE
# Inserted OAXAQUITA BELLA RESTAURANT AND BAKERY
# Inserted JARDIN DE CHINA REST
# Inserted JUST SALAD
# Inserted CHINA KING FOOD
# Inserted PANERA BREAD
# Inserted NEW GOLDEN STAR
# Inserted SUSHI MESHUGA
# Inserted AREPAS PUES MIXTAS
# Inserted NEW STAR CAFE
# Inserted METATE MEXICAN RESTAURANT
# Inserted CAFE BELLA VITA
# Inserted AIR INDIA LOUNGE
# Inserted TO BE THAI
# Inserted TU SONRISA
# Inserted SUBWAY
# Inserted QUE SABOR BAKERY CAFE
# Inserted CITY ISLAND CHINESE RESTAURANT
# Inserted YUMMY CHINESE RESTAURANT
# Inserted PANEORAMA BAKERY
# Inserted BIEN CUIT
# Inserted POLITO'S PIZZA
# Inserted BAGEL FACTORY
# Inserted CROWN DINER
# Inserted LILI'S 57
# Inserted MASAL CAFE & LOUNGE
# Inserted EAST BUFFET & RESTAURANT
# Inserted EL BLOQUE DELI
# Inserted BEST PIZZA ON 1ST.
# Inserted CHELSEA PAPAYA
# Inserted DUNKIN' DONUTS
# Inserted ORIENTAL CHINESE KITCHEN
# Inserted NEW MAGIC CHEF
# Inserted LASANI RESTAURANT
# Inserted UNO CAFE & BILLIARDS
# Inserted STARBUCKS
# Inserted NAPOLEON'S SOUTHERN CUISINE & BAKERY
# Inserted MCDONALD'S
# Inserted MEXICAN RADIO
# Inserted ALEX CAFE & DELI
# Inserted WHITE CASTLE
# Inserted PUPUSERIA EL COMAL
# Inserted NANNI RESTAURANT
# Inserted BIZARRE
# Inserted 765 FOOD MARKET
# Inserted QUALITY CAFE & RESTAURANT
# Inserted AUNT BUTCHIES CAFE
# Inserted SPEEDY DELI
# Inserted EL CERRITO DEL CARMEN RESTAURANT
# Inserted ARETSKY'S PATROON
# Inserted GOOD GOOD TASTE
# Inserted JOE'S OF AVE U
# Inserted MCDONALD'S
# Inserted COLD STONE CREAMERY
# Inserted RAKU II ITS JAPANESE
# Inserted FRIENDLY'S
# Inserted HILTON NEW YORK MAIN KITCHEN
# Inserted POPEYES LOUISIANA KITCHEN
# Inserted CAFE METRO
# Inserted HENRY
# Inserted BURGER KING
# Inserted MON CHER MARKET
# Inserted SOHO BISTRO
# Inserted BUKHARA GRILL
# Inserted MATSU SUSHI
# Inserted OCEAN CHINESE RESTAURANT
# Inserted BROOKLYN WINE YARD
